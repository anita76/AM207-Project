# %% [markdown]
# # AM 207 - Deep Ensembles: A Loss Landscape
#
# ### Circular Toy Dataset Experimentation Notebook

# %% [markdown]
# #### Project Team: Emre Erdem, Carter Nakamoto, Anita Mahinpei

# %%
import tensorflow as tf
#from keras.datasets import cifar10
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Input
#from keras.layers import Conv2D, MaxPooling2D
#from keras import backend as K

import numpy as np
import pandas as pd
import pymc3 as pm

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.preprocessing import scale
from sklearn.datasets import make_moons, make_circles, make_blobs
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline
import seaborn as sns 

import theano
import theano.tensor as T
from warnings import filterwarnings

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.1

# %%
# %config InlineBackend.figure_format = 'retina'
theano.config.gcc.cxxflags = "-Wno-c++11-narrowing"
floatX = theano.config.floatX
filterwarnings('ignore')
sns.set_style('white')

# %% [markdown]
# ## Toy dataset creation

# %%
TOY_DATA_TYPE = "circles"

# Generate a toy dataset for classification
def generate_toy_data():
    if TOY_DATA_TYPE == "moons":
        return make_moons(noise=0.2, random_state=0, n_samples=2000)
    elif TOY_DATA_TYPE == "circles":
        return make_circles(noise=0.1, random_state=0, n_samples=2000, factor=0.5)
    elif TOY_DATA_TYPE == "blobs":
        return make_blobs(cluster_std=0.8, random_state=0, n_samples=2000, centers=np.array([[-1,-1], [1, 1]]))

X, Y = generate_toy_data()
X = X.astype(floatX)
Y = Y.astype(floatX)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.5)

# Define test data points
def generate_test_points(): 
    if TOY_DATA_TYPE == "moons":
        return [(0.5, -0.4), (0.5, 0.8), (0.5, 0.25), (-0.8, 0.5), (1.7, -0.3), (-1.5, -3), 
                (-1.5, 3), (3, -3), (3, 3)]
    elif TOY_DATA_TYPE == "circles":
        return [(0, 0), (0, 2), (0, -2), (2, 0), (-2, 0), (-1, 0), (-0.75, 0), (-0.5, 0),
               (1, 0), (0.75, 0), (0.5, 0), (0, 1), (0, 0.75), (0, 0.5), (0, -1), (0, -0.75), 
                (0, -0.5)]
    elif TOY_DATA_TYPE == "blobs":
        return [(-5, -5), (-5, 3.5), (5, 5), (5, -3.5), (-1, 1), (-1, -1.5), (1, 1.5)]

test_points = generate_test_points()

# %%
# Visualize our test data points
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
ax.scatter(X[Y == 1, 0], X[Y == 1, 1], alpha=0.3, color='red', label='class 1')
ax.scatter(X[Y == 0, 0], X[Y == 0, 1], alpha=0.3, color='blue', label='class 0')
for i in range(len(test_points)):
    pt = test_points[i]
    if i == 0:
        ax.scatter(pt[0], pt[1], alpha=1., s=50, color='black', label='test data')
    else:
        ax.scatter(pt[0], pt[1], alpha=1., s=50, color='black')
ax.set_xlabel('x_1')
ax.set_ylabel('x_2')
ax.set_title('{} classification data with test data points'.format(TOY_DATA_TYPE))
ax.legend(loc='best')
plt.savefig("{}_data_plot.png".format(TOY_DATA_TYPE))

# %% [markdown]
# ## Initial Neural Network Training

# %%
batch_size = 256
num_classes = 2
epochs = 1000

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.5, random_state=42)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
print('x_train shape:', X_train.shape)
print('x_test shape:', X_test.shape)
# Out:
# x_train shape: (1000, 2)
# x_test shape: (1000, 2)

# %%
Y_train.shape
# Out:
# (1000,)

# %%
input_shape = X_train.shape[1]
input_shape
# Out:
# 2

# %%
def get_dropout(input_tensor, p=0.5, mc=False):
    if mc:
        return Dropout(p)(input_tensor)
    else:
        return input_tensor

def get_model(mc=False, p=0.5, act="tanh"):
    if TOY_DATA_TYPE == "blobs" or TOY_DATA_TYPE == "moons" or TOY_DATA_TYPE == "circles":
        inp = Input(shape=(input_shape,))
        x = Dense(64, activation=act)(inp)
        x = get_dropout(x, p=p, mc=mc)
        x = Dense(8, activation=act)(x)
        x = get_dropout(x, p=p, mc=mc)
        out = Dense(1, activation='sigmoid')(x)

        model = Model(inputs=inp, outputs=out)

        model.compile(loss=tf.keras.losses.binary_crossentropy,
                      optimizer=tf.keras.optimizers.Adam(),
                      metrics=['accuracy'])
        return model

# %%
base_model = get_model(mc=False)

# %%
base_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                192
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 520
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 721
# Trainable params: 721
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=20)
history = base_model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[es],
                    validation_data=(X_test, Y_test))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 0.7097 - accuracy: 0.5040 - val_loss: 0.7107 - val_accuracy: 0.5010
# Epoch 2/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7014 - accuracy: 0.5040 - val_loss: 0.7027 - val_accuracy: 0.5080
# Epoch 3/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6962 - accuracy: 0.5170 - val_loss: 0.6975 - val_accuracy: 0.5110
# Epoch 4/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5240 - val_loss: 0.6944 - val_accuracy: 0.5200
# Epoch 5/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6925 - accuracy: 0.5350 - val_loss: 0.6929 - val_accuracy: 0.5330
# Epoch 6/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6920 - accuracy: 0.5620 - val_loss: 0.6923 - val_accuracy: 0.5940
# Epoch 7/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6920 - accuracy: 0.6110 - val_loss: 0.6921 - val_accuracy: 0.6230
# Epoch 8/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6918 - accuracy: 0.6470 - val_loss: 0.6919 - val_accuracy: 0.6440
# Epoch 9/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6916 - accuracy: 0.6350 - val_loss: 0.6917 - val_accuracy: 0.6150
# Epoch 10/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6913 - accuracy: 0.6170 - val_loss: 0.6916 - val_accuracy: 0.5920
# Epoch 11/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6909 - accuracy: 0.5710 - val_loss: 0.6916 - val_accuracy: 0.5460
# Epoch 12/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6905 - accuracy: 0.5390 - val_loss: 0.6915 - val_accuracy: 0.5320
# Epoch 13/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6903 - accuracy: 0.5380 - val_loss: 0.6915 - val_accuracy: 0.5250
# Epoch 14/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6897 - accuracy: 0.5330 - val_loss: 0.6912 - val_accuracy: 0.5250
# Epoch 15/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6893 - accuracy: 0.5400 - val_loss: 0.6907 - val_accuracy: 0.5370
# Epoch 16/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6886 - accuracy: 0.5460 - val_loss: 0.6901 - val_accuracy: 0.5390
# Epoch 17/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6882 - accuracy: 0.5490 - val_loss: 0.6895 - val_accuracy: 0.5440
# Epoch 18/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.
1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9980 - val_loss: 0.0269 - val_accuracy: 0.9920
# Epoch 605/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9980 - val_loss: 0.0268 - val_accuracy: 0.9920
# Epoch 606/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9980 - val_loss: 0.0268 - val_accuracy: 0.9920
# Epoch 607/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9980 - val_loss: 0.0267 - val_accuracy: 0.9920
# Epoch 608/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0162 - accuracy: 0.9980 - val_loss: 0.0267 - val_accuracy: 0.9920
# Epoch 609/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0162 - accuracy: 0.9980 - val_loss: 0.0264 - val_accuracy: 0.9920
# Epoch 610/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9980 - val_loss: 0.0264 - val_accuracy: 0.9920
# Epoch 611/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9980 - val_loss: 0.0266 - val_accuracy: 0.9920
# Epoch 612/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 0.9980 - val_loss: 0.0268 - val_accuracy: 0.9920
# Epoch 613/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9980 - val_loss: 0.0266 - val_accuracy: 0.9920
# Epoch 614/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9980 - val_loss: 0.0266 - val_accuracy: 0.9920
# Epoch 615/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9980 - val_loss: 0.0266 - val_accuracy: 0.9920
# Epoch 616/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9980 - val_loss: 0.0268 - val_accuracy: 0.9920
# Epoch 617/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9970 - val_loss: 0.0267 - val_accuracy: 0.9920
# Epoch 618/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9980 - val_loss: 0.0265 - val_accuracy: 0.9920
# Epoch 619/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9980 - val_loss: 0.0266 - val_accuracy: 0.9920
# Epoch 620/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9980 - val_loss: 0.0266 - val_accuracy: 0.9920
# Epoch 621/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9980 - val_loss: 0.0264 - val_accuracy: 0.9920
# Epoch 622/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9980 - val_loss: 0.0262 - val_accuracy: 0.9920
# Epoch 623/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9980 - val_loss: 0.0262 - val_accuracy: 0.9920
# Epoch 624/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9980 - val_loss: 0.0262 - val_accuracy: 0.9920
# Epoch 625/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9970 - val_loss: 0.0266 - val_accuracy: 0.9920
# Epoch 626/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9970 - val_loss: 0.0265 - val_accuracy: 0.9920
# Epoch 627/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9970 - val_loss: 0.0262 - val_accuracy: 0.9920
# Epoch 628/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9980 - val_loss: 0.0260 - val_accuracy: 0.9920
# Epoch 629/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 0.9980 - val_loss: 0.0262 - val_accuracy: 0.9920
# Epoch 630/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9980 - val_loss: 0.0262 - val_accuracy: 0.9920
# Epoch 631/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9980 - val_loss: 0.0264 - val_accuracy: 0.9920
# Epoch 632/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9970 - val_loss: 0.0266 - val_accuracy: 0.9920
# Epoch 633/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9970 - val_loss: 0.0264 - val_accuracy: 0.9920
# Epoch 634/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9970 - val_loss: 0.0265 - val_accuracy: 0.9920
# Epoch 635/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9970 - val_loss: 0.0262 - val_accuracy: 0.9920
# Epoch 636/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9980 - val_loss: 0.0259 - val_accuracy: 0.9910
# Epoch 637/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9970 - val_loss: 0.0256 - val_accuracy: 0.9920
# Epoch 638/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9980 - val_loss: 0.0260 - val_accuracy: 0.9920
# Epoch 639/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9970 - val_loss: 0.0261 - val_accuracy: 0.9920
# Epoch 640/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9970 - val_loss: 0.0261 - val_accuracy: 0.9920
# Epoch 641/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9970 - val_loss: 0.0265 - val_accuracy: 0.9920
# Epoch 642/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9970 - val_loss: 0.0263 - val_accuracy: 0.9920
# Epoch 643/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9980 - val_loss: 0.0262 - val_accuracy: 0.9920
# Epoch 644/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9980 - val_loss: 0.0261 - val_accuracy: 0.9920
# Epoch 645/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9980 - val_loss: 0.0261 - val_accuracy: 0.9920
# Epoch 646/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9980 - val_loss: 0.0262 - val_accuracy: 0.9920
# Epoch 647/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9980 - val_loss: 0.0259 - val_accuracy: 0.9920
# Epoch 648/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9980 - val_loss: 0.0261 - val_accuracy: 0.9920
# Epoch 649/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9970 - val_loss: 0.0263 - val_accuracy: 0.9920
# Epoch 650/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9970 - val_loss: 0.0265 - val_accuracy: 0.9920
# Epoch 651/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9970 - val_loss: 0.0259 - val_accuracy: 0.9920
# Epoch 652/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9980 - val_loss: 0.0258 - val_accuracy: 0.9920
# Epoch 653/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9970 - val_loss: 0.0257 - val_accuracy: 0.9920
# Epoch 654/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9980 - val_loss: 0.0257 - val_accuracy: 0.9920
# Epoch 655/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9970 - val_loss: 0.0261 - val_accuracy: 0.9920
# Epoch 656/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9970 - val_loss: 0.0257 - val_accuracy: 0.9920
# Epoch 657/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9970 - val_loss: 0.0262 - val_accuracy: 0.9920

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,5))
ax[0].plot(history.history["val_loss"], label="validation loss")
ax[0].plot(history.history["loss"], label="training loss")
ax[0].set_title("plot of loss over iterations")
ax[0].legend()
ax[1].plot(history.history["val_accuracy"], label="validation accuracy")
ax[1].plot(history.history["accuracy"], label="training accuracy")
ax[1].set_title("plot of loss over iterations")
ax[1].legend()
plt.show()

# %%
weights = base_model.get_weights()
base_model.save_weights('initial_model_weights.h5')

# %%
grid = pm.floatX(np.mgrid[-3:3:100j,-3:3:100j])
grid_2d = grid.reshape(2, -1).T
dummy_out = np.ones(grid.shape[1], dtype=np.int8)

# %%
pred2 = base_model.predict(grid_2d)[:,0].flatten()
pred = base_model.predict(X_test)[:,0].flatten() > 0.5

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], pred2.reshape(100, 100), cmap=cmap)
ax.scatter(X_test[pred==0, 0], X_test[pred==0, 1], color='b')
ax.scatter(X_test[pred==1, 0], X_test[pred==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y')
plt.title("prediction probabilities - (Test Set)")
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
# Out:
# Text(0, 0.5, 'posterior predictive mean probability of class label = 0')

# %% [markdown]
# ## Deep Ensemble with Random Initialization

# %%
ensembles = 30
ens_test_probs = []
ens_ood_probs = []
ens_weights = []
grid_preds = []

for i in range(ensembles):
    
    # Fit neural network model
    model = get_model(mc=False)
    nn = model.fit(X_train, Y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=0,
                        callbacks=[es],
                    validation_data=(X_test, Y_test))
    
    #Get Dense model weights
    weights = model.get_weights()
    flat_weight_array = np.array([])
    for weight in weights:
        flat_weight_array = np.concatenate((flat_weight_array, weight.flatten()))
    ens_weights.append(flat_weight_array)
    
    # Accuracy of model
    score = model.evaluate(X_test, Y_test, verbose=0)
    #print('Test loss:', np.round(score[0],2))
    test_prob = model.predict(X_test)
    
    ens_test_probs.append(test_prob)
    print("Iteration: " + str(i+1) +' Test accuracy:'+ str(np.round(score[1],4)))
        
    #Predictions & uncertainty for test points
    ood_prob = model.predict(np.array(test_points))
    ens_ood_probs.append(ood_prob)

    pred2 = model.predict(grid_2d)[:,0].flatten()
    grid_preds.append(pred2)
# Out:
# Iteration: 1 Test accuracy:0.99
# Iteration: 2 Test accuracy:0.991
# Iteration: 3 Test accuracy:0.99
# Iteration: 4 Test accuracy:0.99
# Iteration: 5 Test accuracy:0.991
# Iteration: 6 Test accuracy:0.992
# Iteration: 7 Test accuracy:0.991
# Iteration: 8 Test accuracy:0.991
# Iteration: 9 Test accuracy:0.986
# Iteration: 10 Test accuracy:0.989
# Iteration: 11 Test accuracy:0.991
# Iteration: 12 Test accuracy:0.988
# Iteration: 13 Test accuracy:0.992
# Iteration: 14 Test accuracy:0.993
# Iteration: 15 Test accuracy:0.991
# Iteration: 16 Test accuracy:0.99
# Iteration: 17 Test accuracy:0.991
# Iteration: 18 Test accuracy:0.991
# Iteration: 19 Test accuracy:0.992
# Iteration: 20 Test accuracy:0.993
# Iteration: 21 Test accuracy:0.989
# Iteration: 22 Test accuracy:0.992
# Iteration: 23 Test accuracy:0.992
# Iteration: 24 Test accuracy:0.992
# Iteration: 25 Test accuracy:0.991
# Iteration: 26 Test accuracy:0.99
# Iteration: 27 Test accuracy:0.99
# Iteration: 28 Test accuracy:0.991
# Iteration: 29 Test accuracy:0.992
# Iteration: 30 Test accuracy:0.992

# %%
ens_mean = np.mean(np.array(ens_test_probs),axis=0)
pred_test_labels = (ens_mean > 0.5).astype(np.int) 
score = accuracy_score(Y_test, pred_test_labels)
print("Ensemble prediction accuracy score for test data: ", score)
# Out:
# Ensemble prediction accuracy score for test data:  0.991

# %%
ens_variance = np.std(np.array(ens_ood_probs),axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], ens_variance[i][0]))
# Out:
# uncertainty for test point: (0, 0) : 5.641009465762181e-06
# uncertainty for test point: (0, 2) : 4.498147518461337e-06
# uncertainty for test point: (0, -2) : 2.4843089704518206e-05
# uncertainty for test point: (2, 0) : 4.491711479204241e-06
# uncertainty for test point: (-2, 0) : 1.4176901458995417e-05
# uncertainty for test point: (-1, 0) : 1.4550612831953913e-05
# uncertainty for test point: (-0.75, 0) : 0.0029739290475845337
# uncertainty for test point: (-0.5, 0) : 5.083918040327262e-06
# uncertainty for test point: (1, 0) : 2.5288001779699698e-05
# uncertainty for test point: (0.75, 0) : 0.012069357559084892
# uncertainty for test point: (0.5, 0) : 5.295456503517926e-06
# uncertainty for test point: (0, 1) : 1.286544375034282e-05
# uncertainty for test point: (0, 0.75) : 0.017975671216845512
# uncertainty for test point: (0, 0.5) : 5.218124442762928e-06
# uncertainty for test point: (0, -1) : 6.213581946212798e-05
# uncertainty for test point: (0, -0.75) : 0.009530345909297466
# uncertainty for test point: (0, -0.5) : 5.326349764800398e-06

# %%
df = pd.DataFrame(np.array(ens_weights))

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of deep ensemble weights ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cos_similarity_plot_ensemble.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.mean(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for the deep ensemble model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_ensemble.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.std(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for the deep ensemble model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_ensemble.png".format(TOY_DATA_TYPE))

# %%
tsne = TSNE(n_components=2)
ens_test_probs_pca = tsne.fit_transform(np.array(ens_test_probs).reshape(30, 1000))


plt.scatter(ens_test_probs_pca[:,0], ens_test_probs_pca[:,1])
plt.title("TSNE plot of predictions for the deep ensemble model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_ensemble.png".format(TOY_DATA_TYPE))

# %% [markdown]
# ## Bayesian Dropout Subsampling

# %%
bayes_iters = 30
dropout_post_predictions = []
dropout_ood_probs = []
drop_weights = []
grid_preds = []

for i in range(bayes_iters):
    #Generate random p value for Dropout ratio
    p_rand = np.random.random()
    
    drop_model = get_model(mc=True, p=p_rand)
    
    #Initialize model with pre-trained weights
    drop_model.load_weights('initial_model_weights.h5')
    h_mc = drop_model.fit(X_train, Y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=0,
                        callbacks=[es],
                        validation_data=(X_test, Y_test))
    
    #Get Dense model weights
    weights = drop_model.get_weights()
    flat_weight_array = np.array([])
    for weight in weights:
        flat_weight_array = np.concatenate((flat_weight_array, weight.flatten()))
    drop_weights.append(flat_weight_array)
    
    # Accuracy of model
    score = drop_model.evaluate(X_test, Y_test, verbose=0)
    #print('Test loss:', np.round(score[0],2))
    print("Iteration: " + str(i+1) + " Random p: " + str(np.round(p_rand,2)) + ' Test accuracy: ', str(np.round(score[1],4)))
    
    #Posterior predictions
    y_pred = drop_model.predict(X_test)
    dropout_post_predictions.append(y_pred)
    
    #Predictions & uncertainty for test points
    ood_prob = drop_model.predict(np.array(test_points))
    dropout_ood_probs.append(ood_prob)
    
    pred2 = drop_model.predict(grid_2d)[:,0].flatten()
    grid_preds.append(pred2)
# Out:
# Iteration: 1 Random p: 0.24 Test accuracy:  0.99
# Iteration: 2 Random p: 0.04 Test accuracy:  0.991
# Iteration: 3 Random p: 0.32 Test accuracy:  0.992
# Iteration: 4 Random p: 0.83 Test accuracy:  0.988
# Iteration: 5 Random p: 0.62 Test accuracy:  0.992
# Iteration: 6 Random p: 0.36 Test accuracy:  0.992
# Iteration: 7 Random p: 0.33 Test accuracy:  0.991
# Iteration: 8 Random p: 0.05 Test accuracy:  0.991
# Iteration: 9 Random p: 0.2 Test accuracy:  0.99
# Iteration: 10 Random p: 0.96 Test accuracy:  0.995
# Iteration: 11 Random p: 0.97 Test accuracy:  0.992
# Iteration: 12 Random p: 0.43 Test accuracy:  0.992
# Iteration: 13 Random p: 0.24 Test accuracy:  0.99
# Iteration: 14 Random p: 0.16 Test accuracy:  0.991
# Iteration: 15 Random p: 0.5 Test accuracy:  0.992
# Iteration: 16 Random p: 0.36 Test accuracy:  0.991
# Iteration: 17 Random p: 0.98 Test accuracy:  0.993
# Iteration: 18 Random p: 0.62 Test accuracy:  0.988
# Iteration: 19 Random p: 0.37 Test accuracy:  0.99
# Iteration: 20 Random p: 0.63 Test accuracy:  0.989
# Iteration: 21 Random p: 0.25 Test accuracy:  0.99
# Iteration: 22 Random p: 0.21 Test accuracy:  0.989
# Iteration: 23 Random p: 0.92 Test accuracy:  0.99
# Iteration: 24 Random p: 0.34 Test accuracy:  0.99
# Iteration: 25 Random p: 0.08 Test accuracy:  0.992
# Iteration: 26 Random p: 0.16 Test accuracy:  0.991
# Iteration: 27 Random p: 0.54 Test accuracy:  0.992
# Iteration: 28 Random p: 0.53 Test accuracy:  0.989
# Iteration: 29 Random p: 0.54 Test accuracy:  0.989
# Iteration: 30 Random p: 0.01 Test accuracy:  0.991

# %%
df = pd.DataFrame(np.array(drop_weights))

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0.95, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian dropout weights ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cos_similarity_plot_dropout.png".format(TOY_DATA_TYPE))

# %%
dropout_posterior_mean_preds = np.mean(np.array(dropout_post_predictions),axis=0)
dropout_posterior_mean_preds.shape
# Out:
# (1000, 1)

# %%
dropout_pred_test_labels = (dropout_posterior_mean_preds > 0.5).astype(np.int) 
dropout_acc_score = accuracy_score(Y_test, dropout_pred_test_labels)
print("Bayesian Dropout posterior predictive mean accuracy score for test data: ", dropout_acc_score)
# Out:
# Bayesian Dropout posterior predictive mean accuracy score for test data:  0.992

# %%
drop_ood_variance = np.std(np.array(dropout_ood_probs),axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], drop_ood_variance[i][0]))
# Out:
# uncertainty for test point: (0, 0) : 1.0333541666796009e-07
# uncertainty for test point: (0, 2) : 4.62625437958053e-10
# uncertainty for test point: (0, -2) : 8.576826644457469e-07
# uncertainty for test point: (2, 0) : 5.778136302758696e-10
# uncertainty for test point: (-2, 0) : 5.685061523763579e-07
# uncertainty for test point: (-1, 0) : 2.1642877072736155e-06
# uncertainty for test point: (-0.75, 0) : 0.018584255129098892
# uncertainty for test point: (-0.5, 0) : 1.3086018668673205e-07
# uncertainty for test point: (1, 0) : 2.1237890734937537e-07
# uncertainty for test point: (0.75, 0) : 0.029206572100520134
# uncertainty for test point: (0.5, 0) : 1.2917548986024485e-07
# uncertainty for test point: (0, 1) : 4.33838840763201e-06
# uncertainty for test point: (0, 0.75) : 0.023142021149396896
# uncertainty for test point: (0, 0.5) : 1.7301086074894556e-07
# uncertainty for test point: (0, -1) : 1.6288347978843376e-05
# uncertainty for test point: (0, -0.75) : 0.027954479679465294
# uncertainty for test point: (0, -0.5) : 9.430414138478227e-08

# %%
dropout_pred_test_labels.shape
# Out:
# (1000, 1)

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.mean(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for dropout model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_dropout.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.std(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for dropout model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_dropout.png".format(TOY_DATA_TYPE))

# %%
tsne = TSNE(n_components=2)
ens_test_probs_pca = tsne.fit_transform(np.array(ens_test_probs).reshape(30, 1000))


plt.scatter(ens_test_probs_pca[:,0], ens_test_probs_pca[:,1])
plt.title("TSNE plot of predictions for dropout model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_dropout.png".format(TOY_DATA_TYPE))

# %% [markdown]
# ## Random Subspace Sampling

# %%
models = []
random_weights= []
# iterate over different samples
for i in range(bayes_iters):
    # make a new NN with the same layout
    model2 = get_model(mc=False)
    # add random vector to presaved model weights
    model2.load_weights('initial_model_weights.h5')
    #Added scale to regularize randomness
    weights = [model2.get_weights()[j] + np.random.normal(size = model2.get_weights()[j].shape, scale=0.2) for j in range(len(model.get_weights()))]
    model2.set_weights(weights)
    #Get Dense model weights
    weights = model2.get_weights()
    flat_weight_array = np.array([])
    for weight in weights:
        flat_weight_array = np.concatenate((flat_weight_array, weight.flatten()))
    random_weights.append(flat_weight_array)
    models.append(model2)

# %%
random_post_predictions = []
grid_preds = []
random_ood_probs = []

for model in models: 
    y_pred = model.predict(X_test)
    random_post_predictions.append(y_pred)
    pred2 = model.predict(grid_2d)[:,0].flatten()
    grid_preds.append(pred2)
    #Predictions & uncertainty for test points
    ood_prob = model.predict(np.array(test_points))
    random_ood_probs.append(ood_prob)
    
random_posterior_mean_preds = np.mean(np.array(random_post_predictions),axis=0)
random_pred_test_labels = (random_posterior_mean_preds > 0.5).astype(np.int) 
random_acc_score = accuracy_score(Y_test, random_pred_test_labels)
print("Random subspace posterior predictive Test set mean accuracy score for test data: ", random_acc_score)
# Out:
# Random subspace posterior predictive Test set mean accuracy score for test data:  0.989

# %%
random_ood_variance = np.std(np.array(random_ood_probs),axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], random_ood_variance[i][0]))
# Out:
# uncertainty for test point: (0, 0) : 2.470239451213274e-06
# uncertainty for test point: (0, 2) : 8.935538744481164e-07
# uncertainty for test point: (0, -2) : 0.0001325847115367651
# uncertainty for test point: (2, 0) : 1.3052999747742433e-07
# uncertainty for test point: (-2, 0) : 1.4985829693614505e-05
# uncertainty for test point: (-1, 0) : 0.021710624918341637
# uncertainty for test point: (-0.75, 0) : 0.120330810546875
# uncertainty for test point: (-0.5, 0) : 0.012420660816133022
# uncertainty for test point: (1, 0) : 0.01956605724990368
# uncertainty for test point: (0.75, 0) : 0.1442015916109085
# uncertainty for test point: (0.5, 0) : 0.031816769391298294
# uncertainty for test point: (0, 1) : 0.02387957274913788
# uncertainty for test point: (0, 0.75) : 0.13766804337501526
# uncertainty for test point: (0, 0.5) : 0.03075232356786728
# uncertainty for test point: (0, -1) : 0.005629397928714752
# uncertainty for test point: (0, -0.75) : 0.11906392872333527
# uncertainty for test point: (0, -0.5) : 0.0064614941366016865

# %%
df = pd.DataFrame(np.array(random_weights))

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian random sampling ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cosine_similarity_plot_random.png".format(TOY_DATA_TYPE))

# %%
fig, ax = plt.subplots(figsize=(16, 9))
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
contour = ax.contourf(grid[0], grid[1], np.mean(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for random sampling model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_random.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.std(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for random sampling model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_posterior_predictive_plot_random.png".format(TOY_DATA_TYPE))

# %%
tsne = TSNE(n_components=2)
ens_test_probs_pca = tsne.fit_transform(np.array(ens_test_probs).reshape(30, 1000))


plt.scatter(ens_test_probs_pca[:,0], ens_test_probs_pca[:,1])
plt.title("TSNE plot of predictions for random sampling model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_random.png".format(TOY_DATA_TYPE))

# %% [markdown]
# ### HMC

# %%
def construct_nn(ann_input, ann_output):
    n_hidden1 = 64
    n_hidden2 = 8

    # Initialize random weights between each layer
    model = get_model(mc=False)
    model.load_weights('initial_model_weights.h5')
    ws = model.get_weights()
    init_1 = ws[0].astype(floatX)
    init_2 = ws[2].astype(floatX)
    init_out = ws[4].flatten().astype(floatX)
    init_b1 = ws[1].astype(floatX)
    init_b2 = ws[3].astype(floatX)
    init_bout = ws[5].astype(floatX)

    with pm.Model() as neural_network:
        # Trick: Turn inputs and outputs into shared variables using the data container pm.Data
        # It's still the same thing, but we can later change the values of the shared variable
        # (to switch in the test-data later) and pymc3 will just use the new data.
        # Kind-of like a pointer we can redirect.
        # For more info, see: http://deeplearning.net/software/theano/library/compile/shared.html
        ann_input = pm.Data('ann_input', ann_input)
        ann_output = pm.Data('ann_output', ann_output)

        # Weights from input to hidden layer
        weights_in_1 = pm.Normal('w_in_1', 0, sigma=1,
                                 shape=(X.shape[1], n_hidden1),
                                 testval=init_1)
        biases_in_1 = pm.Normal('b_in_1', 0, sigma=1,
                                 shape=(n_hidden1,),
                                 testval=init_b1)

        # Weights from 1st to 2nd layer
        weights_1_2 = pm.Normal('w_1_2', 0, sigma=1,
                                shape=(n_hidden1, n_hidden2),
                                testval=init_2)
        biases_1_2 = pm.Normal('b_1_2', 0, sigma=1,
                                 shape=(n_hidden2,),
                                 testval=init_b2)

        # Weights from hidden layer to output
        weights_2_out = pm.Normal('w_2_out', 0, sigma=1,
                                  shape=(n_hidden2,),
                                  testval=init_out)
        biases_2_out = pm.Normal('b_3_out', 0, sigma=1,
                                 shape=(1,),
                                 testval=init_bout)

        # Build neural-network using tanh activation function
        act_1 = pm.math.tanh(pm.math.dot(ann_input,
                                         weights_in_1)+biases_in_1)
        act_2 = pm.math.tanh(pm.math.dot(act_1,
                                         weights_1_2)+biases_1_2)
        act_out = pm.math.sigmoid(pm.math.dot(act_2,
                                              weights_2_out)+biases_2_out)

        # Binary classification -> Bernoulli likelihood
        out = pm.Bernoulli('out',
                           act_out,
                           observed=ann_output,
                           total_size=Y_train.shape[0] # IMPORTANT for minibatches
                          )
    return neural_network

neural_network = construct_nn(X_train, Y_train)

# %%
from pymc3.theanof import set_tt_rng, MRG_RandomStreams
set_tt_rng(MRG_RandomStreams(42))

# %%
with neural_network:
    steps = pm.NUTS()
    #use the specify sampler to sample from the posterior of the model
    trace = pm.sample(5000, step=steps, tune=1000, chains=1)
# Out:
# Sequential sampling (1 chains in 1 job)
# NUTS: [b_3_out, w_2_out, b_1_2, w_1_2, b_in_1, w_in_1]
# Sampling chain 0, 12 divergences: 100%|██████████| 6000/6000 [1:14:12<00:00,  1.35it/s]
# There were 12 divergences after tuning. Increase `target_accept` or reparameterize.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
pm.set_data(new_data={'ann_input': X_test, 'ann_output': Y_test}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)

# %%
pred = ppc["out"].mean(axis=0) > 0.5

# %%
print('Test Set Accuracy = {}%'.format((Y_test == pred).mean() * 100))
# Out:
# Test Set Accuracy = 99.1%

# %%
pm.set_data(new_data={'ann_input': np.array(test_points), 'ann_output': np.ones(len(test_points), dtype=np.int8)}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)
ood_variance = np.std(ppc["out"],axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], ood_variance[i]))
# Out:
# uncertainty for test point: (0, 0) : 0.0
# uncertainty for test point: (0, 2) : 0.023423999999999986
# uncertainty for test point: (0, -2) : 0.005964000000000059
# uncertainty for test point: (2, 0) : 0.023424000000000132
# uncertainty for test point: (-2, 0) : 0.019600000000000183
# uncertainty for test point: (-1, 0) : 0.005964000000000043
# uncertainty for test point: (-0.75, 0) : 0.19239999999999965
# uncertainty for test point: (-0.5, 0) : 0.005964000000000084
# uncertainty for test point: (1, 0) : 0.00793600000000005
# uncertainty for test point: (0.75, 0) : 0.2499360000000004
# uncertainty for test point: (0.5, 0) : 0.0
# uncertainty for test point: (0, 1) : 0.005964000000000063
# uncertainty for test point: (0, 0.75) : 0.24422400000000158
# uncertainty for test point: (0, 0.5) : 0.0019960000000000004
# uncertainty for test point: (0, -1) : 0.001996000000000004
# uncertainty for test point: (0, -0.75) : 0.23745599999999845
# uncertainty for test point: (0, -0.5) : 0.0

# %%
pm.set_data(new_data={'ann_input': grid_2d, 'ann_output': dummy_out}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc["out"].mean(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for HMC model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_hmc.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc["out"].std(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for HMC model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_hmc.png".format(TOY_DATA_TYPE))

# %%
pm.set_data(new_data={'ann_input': grid_2d, 'ann_output': dummy_out}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)["out"]
tsne = TSNE(n_components=2)
ppc_pca = tsne.fit_transform(ppc)


plt.plot(ppc_pca[:,0], ppc_pca[:,1], linestyle = "", marker = "o")
plt.title("TSNE plot of predictions for HMC model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_hmc.png".format(TOY_DATA_TYPE))

# %%
combined = trace["w_in_1"].reshape(-1, 64*2)
combined = np.concatenate((combined, trace["w_1_2"].reshape(-1, 64*8)), axis=1)
combined = np.concatenate((combined, trace["w_2_out"]), axis=1)
combined = np.concatenate((combined, trace["b_in_1"]), axis=1)
combined = np.concatenate((combined, trace["b_1_2"]), axis=1)
combined = np.concatenate((combined, trace["b_3_out"]), axis=1)

df = pd.DataFrame(np.array(combined)[-30:])

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian HMC model ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cos_similarity_plot_hmc.png".format(TOY_DATA_TYPE))

# %% [markdown]
# ### ADVI

# %%
neural_network = construct_nn(X_train, Y_train)

# %%
with neural_network:
    steps = pm.ADVI()
    #use the specify sampler to sample from the posterior of the model
    approx = pm.fit(n=30000, method=steps)
# Out:
# Average Loss = 620.03: 100%|██████████| 30000/30000 [01:08<00:00, 435.01it/s]
# Finished [100%]: Average Loss = 619.77

# %%
# create symbolic input
x_sym = T.matrix('X_test')
# symbolic number of samples is supported, we build vectorized posterior on the fly
n_sym = T.iscalar('n')
# Do not forget test_values or set theano.config.compute_test_value = 'off'
x_sym.tag.test_value = np.empty_like(X_test)
n_sym.tag.test_value = X_test.shape[1]
_sample_proba = approx.sample_node(neural_network.out.distribution.p,
                                   size=n_sym,
                                   more_replacements={neural_network['ann_input']: x_sym})
# Efficient vectorized form of sampling is used
sample_proba = theano.function([x_sym, n_sym], _sample_proba)
pred = (sample_proba(X_test, 500).mean(0) > 0.5) * 1
print('Test Set Accuracy = {}%'.format((Y_test == pred).mean() * 100))
# Out:
# Test Set Accuracy = 98.9%

# %%
ppc = sample_proba(test_points ,500)
ood_variance = np.std(ppc,axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], ood_variance[i]))
# Out:
# uncertainty for test point: (0, 0) : 0.0013335950656750447
# uncertainty for test point: (0, 2) : 0.02848733138583136
# uncertainty for test point: (0, -2) : 0.054458929908839424
# uncertainty for test point: (2, 0) : 0.025811564952307443
# uncertainty for test point: (-2, 0) : 0.03722690305269878
# uncertainty for test point: (-1, 0) : 0.05481854731016957
# uncertainty for test point: (-0.75, 0) : 0.101129854116061
# uncertainty for test point: (-0.5, 0) : 0.043255422928768675
# uncertainty for test point: (1, 0) : 0.05803755418096433
# uncertainty for test point: (0.75, 0) : 0.09926607998458013
# uncertainty for test point: (0.5, 0) : 0.043755379944288963
# uncertainty for test point: (0, 1) : 0.059161307661379246
# uncertainty for test point: (0, 0.75) : 0.0972356642349845
# uncertainty for test point: (0, 0.5) : 0.0360872216796245
# uncertainty for test point: (0, -1) : 0.05417930271394484
# uncertainty for test point: (0, -0.75) : 0.09485059308040518
# uncertainty for test point: (0, -0.5) : 0.03884016861465743

# %%
# populate grid with average predictions
ppc = sample_proba(grid_2d ,500)
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc.mean(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for ADVI model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_advi.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc.std(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for ADVI model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_advi.png".format(TOY_DATA_TYPE))

# %%
ppc = sample_proba(X_test ,500)
tsne = TSNE(n_components=2)
ppc_pca = tsne.fit_transform(ppc)


plt.plot(ppc_pca[:,0], ppc_pca[:,1], linestyle = "", marker = "o")
plt.title("TSNE plot of predictions for ADVI model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_advi.png".format(TOY_DATA_TYPE))

# %%
combined = trace["w_in_1"].reshape(-1, 64*2)
combined = np.concatenate((combined, trace["w_1_2"].reshape(-1, 64*8)), axis=1)
combined = np.concatenate((combined, trace["w_2_out"]), axis=1)
combined = np.concatenate((combined, trace["b_in_1"]), axis=1)
combined = np.concatenate((combined, trace["b_1_2"]), axis=1)
combined = np.concatenate((combined, trace["b_3_out"]), axis=1)

df = pd.DataFrame(np.array(combined)[-30:])

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian ADVI model ({} data) ".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cosine_similarity_plot_advi.png".format(TOY_DATA_TYPE))
