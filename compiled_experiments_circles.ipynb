# %% [markdown]
# # AM 207 - Deep Ensembles: A Loss Landscape
#
# ### Circular Toy Dataset Experimentation Notebook

# %% [markdown]
# #### Project Team: Emre Erdem, Carter Nakamoto, Anita Mahinpei

# %%
import tensorflow as tf
#from keras.datasets import cifar10
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Input
#from keras.layers import Conv2D, MaxPooling2D
#from keras import backend as K

import numpy as np
import pandas as pd
import pymc3 as pm

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.preprocessing import scale
from sklearn.datasets import make_moons, make_circles, make_blobs
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline
import seaborn as sns 

import theano
import theano.tensor as T
from warnings import filterwarnings

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.1

# %%
# %config InlineBackend.figure_format = 'retina'
theano.config.gcc.cxxflags = "-Wno-c++11-narrowing"
floatX = theano.config.floatX
filterwarnings('ignore')
sns.set_style('white')

# %% [markdown]
# ## Toy dataset creation

# %%
TOY_DATA_TYPE = "circles"

# Generate a toy dataset for classification
def generate_toy_data():
    if TOY_DATA_TYPE == "moons":
        return make_moons(noise=0.2, random_state=0, n_samples=2000)
    elif TOY_DATA_TYPE == "circles":
        return make_circles(noise=0.1, random_state=0, n_samples=2000, factor=0.5)
    elif TOY_DATA_TYPE == "blobs":
        return make_blobs(cluster_std=0.8, random_state=0, n_samples=2000, centers=np.array([[-1,-1], [1, 1]]))

X, Y = generate_toy_data()
X = X.astype(floatX)
Y = Y.astype(floatX)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.5)

# Define test data points
def generate_test_points(): 
    if TOY_DATA_TYPE == "moons":
        return [(0.5, -0.4), (0.5, 0.8), (0.5, 0.25), (-0.8, 0.5), (1.7, -0.3), (-1.5, -3), 
                (-1.5, 3), (3, -3), (3, 3)]
    elif TOY_DATA_TYPE == "circles":
        return [(0, 0), (0, 2), (0, -2), (2, 0), (-2, 0), (-1, 0), (-0.75, 0), (-0.5, 0),
               (1, 0), (0.75, 0), (0.5, 0), (0, 1), (0, 0.75), (0, 0.5), (0, -1), (0, -0.75), 
                (0, -0.5)]
    elif TOY_DATA_TYPE == "blobs":
        return [(-5, -5), (-5, 3.5), (5, 5), (5, -3.5), (-1, 1), (-1, -1.5), (1, 1.5)]

test_points = generate_test_points()

# %%
# Visualize our test data points
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
ax.scatter(X[Y == 1, 0], X[Y == 1, 1], alpha=0.3, color='red', label='class 1')
ax.scatter(X[Y == 0, 0], X[Y == 0, 1], alpha=0.3, color='blue', label='class 0')
for i in range(len(test_points)):
    pt = test_points[i]
    if i == 0:
        ax.scatter(pt[0], pt[1], alpha=1., s=50, color='black', label='test data')
    else:
        ax.scatter(pt[0], pt[1], alpha=1., s=50, color='black')
ax.set_xlabel('x_1')
ax.set_ylabel('x_2')
ax.set_title('{} classification data with test data points'.format(TOY_DATA_TYPE))
ax.legend(loc='best')
plt.savefig("{}_data_plot.png".format(TOY_DATA_TYPE))

# %% [markdown]
# ## Initial Neural Network Training

# %%
batch_size = 256
num_classes = 2
epochs = 1000

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.5, random_state=42)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
print('x_train shape:', X_train.shape)
print('x_test shape:', X_test.shape)
# Out:
# x_train shape: (1000, 2)
# x_test shape: (1000, 2)

# %%
Y_train.shape
# Out:
# (1000,)

# %%
input_shape = X_train.shape[1]
input_shape
# Out:
# 2

# %%
def get_dropout(input_tensor, p=0.5, mc=False):
    if mc:
        return Dropout(p)(input_tensor)
    else:
        return input_tensor

def get_model(mc=False, p=0.5, act="tanh"):
    if TOY_DATA_TYPE == "blobs" or TOY_DATA_TYPE == "moons" or TOY_DATA_TYPE == "circles":
        inp = Input(shape=(input_shape,))
        x = Dense(64, activation=act)(inp)
        x = get_dropout(x, p=p, mc=mc)
        x = Dense(8, activation=act)(x)
        x = get_dropout(x, p=p, mc=mc)
        out = Dense(1, activation='sigmoid')(x)

        model = Model(inputs=inp, outputs=out)

        model.compile(loss=tf.keras.losses.binary_crossentropy,
                      optimizer=tf.keras.optimizers.Adam(),
                      metrics=['accuracy'])
        return model

# %%
base_model = get_model(mc=False)

# %%
base_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                192
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 520
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 721
# Trainable params: 721
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=20)
history = base_model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[es],
                    validation_data=(X_test, Y_test))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.6981 - accuracy: 0.4980 - val_loss: 0.6994 - val_accuracy: 0.4910
# Epoch 2/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6956 - accuracy: 0.5080 - val_loss: 0.6967 - val_accuracy: 0.5010
# Epoch 3/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.5120 - val_loss: 0.6949 - val_accuracy: 0.5080
# Epoch 4/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6929 - accuracy: 0.5250 - val_loss: 0.6938 - val_accuracy: 0.5250
# Epoch 5/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6929 - accuracy: 0.5480 - val_loss: 0.6932 - val_accuracy: 0.5820
# Epoch 6/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6927 - accuracy: 0.5990 - val_loss: 0.6931 - val_accuracy: 0.5990
# Epoch 7/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6926 - accuracy: 0.6090 - val_loss: 0.6931 - val_accuracy: 0.5910
# Epoch 8/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6925 - accuracy: 0.5890 - val_loss: 0.6931 - val_accuracy: 0.5560
# Epoch 9/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6924 - accuracy: 0.5620 - val_loss: 0.6932 - val_accuracy: 0.5410
# Epoch 10/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6923 - accuracy: 0.5470 - val_loss: 0.6933 - val_accuracy: 0.5270
# Epoch 11/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6921 - accuracy: 0.5370 - val_loss: 0.6934 - val_accuracy: 0.5260
# Epoch 12/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6920 - accuracy: 0.5340 - val_loss: 0.6933 - val_accuracy: 0.5310
# Epoch 13/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6922 - accuracy: 0.5340 - val_loss: 0.6934 - val_accuracy: 0.5200
# Epoch 14/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6918 - accuracy: 0.5370 - val_loss: 0.6933 - val_accuracy: 0.5240
# Epoch 15/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6918 - accuracy: 0.5390 - val_loss: 0.6930 - val_accuracy: 0.5310
# Epoch 16/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6915 - accuracy: 0.5410 - val_loss: 0.6928 - val_accuracy: 0.5380
# Epoch 17/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6914 - accuracy: 0.5410 - val_loss: 0.6926 - val_accuracy: 0.5370
# Epoch 18/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6911 - accuracy: 0.5420 - val_loss: 0.6924 - val_accuracy: 0.5390
# Epoch 19/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6910 - accuracy: 0.5420 - val_loss: 0.6920 - val_accuracy: 0.5480
# Epoch 20/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6907 - accuracy: 0.5580 - val_loss: 0.6918 - val_accuracy: 0.5530
# Epoch 21/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6903 - accuracy: 0.5660 - val_loss: 0.6915 - val_accuracy: 0.5490
# Epoch 22/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.
1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3955 - accuracy: 0.9620 - val_loss: 0.3986 - val_accuracy: 0.9640
# Epoch 117/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3929 - accuracy: 0.9650 - val_loss: 0.3960 - val_accuracy: 0.9630
# Epoch 118/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3903 - accuracy: 0.9660 - val_loss: 0.3935 - val_accuracy: 0.9640
# Epoch 119/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3879 - accuracy: 0.9670 - val_loss: 0.3911 - val_accuracy: 0.9650
# Epoch 120/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3855 - accuracy: 0.9670 - val_loss: 0.3886 - val_accuracy: 0.9640
# Epoch 121/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3827 - accuracy: 0.9650 - val_loss: 0.3860 - val_accuracy: 0.9630
# Epoch 122/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3802 - accuracy: 0.9670 - val_loss: 0.3835 - val_accuracy: 0.9630
# Epoch 123/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3777 - accuracy: 0.9670 - val_loss: 0.3811 - val_accuracy: 0.9640
# Epoch 124/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3752 - accuracy: 0.9670 - val_loss: 0.3786 - val_accuracy: 0.9650
# Epoch 125/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3726 - accuracy: 0.9680 - val_loss: 0.3761 - val_accuracy: 0.9630
# Epoch 126/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3702 - accuracy: 0.9660 - val_loss: 0.3737 - val_accuracy: 0.9630
# Epoch 127/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3676 - accuracy: 0.9660 - val_loss: 0.3712 - val_accuracy: 0.9660
# Epoch 128/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3651 - accuracy: 0.9670 - val_loss: 0.3686 - val_accuracy: 0.9670
# Epoch 129/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3626 - accuracy: 0.9690 - val_loss: 0.3662 - val_accuracy: 0.9680
# Epoch 130/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3601 - accuracy: 0.9680 - val_loss: 0.3637 - val_accuracy: 0.9670
# Epoch 131/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3575 - accuracy: 0.9670 - val_loss: 0.3613 - val_accuracy: 0.9650
# Epoch 132/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3550 - accuracy: 0.9690 - val_loss: 0.3589 - val_accuracy: 0.9650
# Epoch 133/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3525 - accuracy: 0.9690 - val_loss: 0.3565 - val_accuracy: 0.9650
# Epoch 134/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3500 - accuracy: 0.9690 - val_loss: 0.3541 - val_accuracy: 0.9650
# Epoch 135/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3476 - accuracy: 0.9690 - val_loss: 0.3518 - val_accuracy: 0.9670
# Epoch 136/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3450 - accuracy: 0.9700 - val_loss: 0.3493 - val_accuracy: 0.9670
# Epoch 137/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3425 - accuracy: 0.9690 - val_loss: 0.3467 - val_accuracy: 0.9670
# Epoch 138/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3400 - accuracy: 0.9700 - val_loss: 0.3442 - val_accuracy: 0.9660
# Epoch 139/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3374 - accuracy: 0.9680 - val_loss: 0.3416 - val_accuracy: 0.9670
# Epoch 140/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3350 - accuracy: 0.9680 - val_loss: 0.3392 - val_accuracy: 0.9680
# Epoch 141/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3326 - accuracy: 0.9700 - val_loss: 0.3367 - val_accuracy: 0.9680
# Epoch 142/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3299 - accuracy: 0.9690 - val_loss: 0.3343 - val_accuracy: 0.9670
# Epoch 143/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3274 - accuracy: 0.9690 - val_loss: 0.3318 - val_accuracy: 0.9660
# Epoch 144/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3249 - accuracy: 0.9680 - val_loss: 0.3292 - val_accuracy: 0.9680
# Epoch 145/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3224 - accuracy: 0.9680 - val_loss: 0.3268 - val_accuracy: 0.9690
# Epoch 146/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3197 - accuracy: 0.9680 - val_loss: 0.3243 - val_accuracy: 0.9680
# Epoch 147/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.
1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9970 - val_loss: 0.0266 - val_accuracy: 0.9910

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,5))
ax[0].plot(history.history["val_loss"], label="validation loss")
ax[0].plot(history.history["loss"], label="training loss")
ax[0].set_title("plot of loss over iterations")
ax[0].legend()
ax[1].plot(history.history["val_accuracy"], label="validation accuracy")
ax[1].plot(history.history["accuracy"], label="training accuracy")
ax[1].set_title("plot of loss over iterations")
ax[1].legend()
plt.show()

# %%
weights = base_model.get_weights()
base_model.save_weights('initial_model_weights.h5')

# %%
grid = pm.floatX(np.mgrid[-3:3:100j,-3:3:100j])
grid_2d = grid.reshape(2, -1).T
dummy_out = np.ones(grid.shape[1], dtype=np.int8)

# %%
pred2 = base_model.predict(grid_2d)[:,0].flatten()
pred = base_model.predict(X_test)[:,0].flatten() > 0.5

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], pred2.reshape(100, 100), cmap=cmap)
ax.scatter(X_test[pred==0, 0], X_test[pred==0, 1], color='b')
ax.scatter(X_test[pred==1, 0], X_test[pred==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y')
plt.title("prediction probabilities - (Test Set)")
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
# Out:
# Text(0, 0.5, 'Posterior predictive mean probability of class label = 0')

# %% [markdown]
# ## Deep Ensemble with Random Initialization

# %%
ensembles = 30
ens_test_probs = []
ens_ood_probs = []
ens_weights = []
grid_preds = []

for i in range(ensembles):
    
    # Fit neural network model
    model = get_model(mc=False)
    nn = model.fit(X_train, Y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=0,
                        callbacks=[es],
                    validation_data=(X_test, Y_test))
    
    #Get Dense model weights
    weights = model.get_weights()
    flat_weight_array = np.array([])
    for weight in weights:
        flat_weight_array = np.concatenate((flat_weight_array, weight.flatten()))
    ens_weights.append(flat_weight_array)
    
    # Accuracy of model
    score = model.evaluate(X_test, Y_test, verbose=0)
    #print('Test loss:', np.round(score[0],2))
    test_prob = model.predict(X_test)
    
    ens_test_probs.append(test_prob)
    print("Iteration: " + str(i+1) +' Test accuracy:'+ str(np.round(score[1],4)))
        
    #Predictions & uncertainty for test points
    ood_prob = model.predict(np.array(test_points))
    ens_ood_probs.append(ood_prob)

    pred2 = model.predict(grid_2d)[:,0].flatten()
    grid_preds.append(pred2)
# Out:
# Iteration: 1 Test accuracy:0.991
# Iteration: 2 Test accuracy:0.991
# Iteration: 3 Test accuracy:0.992
# Iteration: 4 Test accuracy:0.992
# Iteration: 5 Test accuracy:0.991
# Iteration: 6 Test accuracy:0.991
# Iteration: 7 Test accuracy:0.993
# Iteration: 8 Test accuracy:0.991
# Iteration: 9 Test accuracy:0.992
# Iteration: 10 Test accuracy:0.989
# Iteration: 11 Test accuracy:0.991
# Iteration: 12 Test accuracy:0.992
# Iteration: 13 Test accuracy:0.991
# Iteration: 14 Test accuracy:0.991
# Iteration: 15 Test accuracy:0.992
# Iteration: 16 Test accuracy:0.992
# Iteration: 17 Test accuracy:0.991
# Iteration: 18 Test accuracy:0.99
# Iteration: 19 Test accuracy:0.991
# Iteration: 20 Test accuracy:0.991
# Iteration: 21 Test accuracy:0.991
# Iteration: 22 Test accuracy:0.991
# Iteration: 23 Test accuracy:0.989
# Iteration: 24 Test accuracy:0.988
# Iteration: 25 Test accuracy:0.992
# Iteration: 26 Test accuracy:0.992
# Iteration: 27 Test accuracy:0.991
# Iteration: 28 Test accuracy:0.991
# Iteration: 29 Test accuracy:0.992
# Iteration: 30 Test accuracy:0.992

# %%
ens_mean = np.mean(np.array(ens_test_probs),axis=0)
pred_test_labels = (ens_mean > 0.5).astype(np.int) 
score = accuracy_score(Y_test, pred_test_labels)
print("Ensemble prediction accuracy score for test data: ", score)
# Out:
# Ensemble prediction accuracy score for test data:  0.992

# %%
ens_variance = np.std(np.array(ens_ood_probs),axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], ens_variance[i][0]))
# Out:
# uncertainty for test point: (0, 0) : 3.8786561162851285e-06
# uncertainty for test point: (0, 2) : 1.0552807907515671e-05
# uncertainty for test point: (0, -2) : 4.175365756964311e-05
# uncertainty for test point: (2, 0) : 1.8698714484344237e-05
# uncertainty for test point: (-2, 0) : 1.3604580999526661e-05
# uncertainty for test point: (-1, 0) : 1.744142355164513e-05
# uncertainty for test point: (-0.75, 0) : 0.00640551932156086
# uncertainty for test point: (-0.5, 0) : 3.534433744789567e-06
# uncertainty for test point: (1, 0) : 3.365634256624617e-05
# uncertainty for test point: (0.75, 0) : 0.0055880132131278515
# uncertainty for test point: (0.5, 0) : 3.511999238980934e-06
# uncertainty for test point: (0, 1) : 2.6931513275485486e-05
# uncertainty for test point: (0, 0.75) : 0.016825105994939804
# uncertainty for test point: (0, 0.5) : 3.364291387697449e-06
# uncertainty for test point: (0, -1) : 6.527981167891994e-05
# uncertainty for test point: (0, -0.75) : 0.007687462959438562
# uncertainty for test point: (0, -0.5) : 3.418203050387092e-06

# %%
df = pd.DataFrame(np.array(ens_weights))

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of deep ensemble weights ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cos_similarity_plot_ensemble.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.mean(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for the deep ensemble model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_ensemble.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.std(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for the deep ensemble model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_ensemble.png".format(TOY_DATA_TYPE))

# %%
tsne = TSNE(n_components=2)
ens_test_probs_pca = tsne.fit_transform(np.array(ens_test_probs).reshape(30, 1000))


plt.scatter(ens_test_probs_pca[:,0], ens_test_probs_pca[:,1])
plt.title("TSNE plot of predictions for the deep ensemble model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_ensemble.png".format(TOY_DATA_TYPE))

# %% [markdown]
# ## Bayesian Dropout Subsampling

# %%
bayes_iters = 30
dropout_post_predictions = []
dropout_ood_probs = []
drop_weights = []
grid_preds = []

for i in range(bayes_iters):
    #Generate random p value for Dropout ratio
    p_rand = np.random.random()
    
    drop_model = get_model(mc=True, p=p_rand)
    
    #Initialize model with pre-trained weights
    drop_model.load_weights('initial_model_weights.h5')
    h_mc = drop_model.fit(X_train, Y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=0,
                        callbacks=[es],
                        validation_data=(X_test, Y_test))
    
    #Get Dense model weights
    weights = drop_model.get_weights()
    flat_weight_array = np.array([])
    for weight in weights:
        flat_weight_array = np.concatenate((flat_weight_array, weight.flatten()))
    drop_weights.append(flat_weight_array)
    
    # Accuracy of model
    score = drop_model.evaluate(X_test, Y_test, verbose=0)
    #print('Test loss:', np.round(score[0],2))
    print("Iteration: " + str(i+1) + " Random p: " + str(np.round(p_rand,2)) + ' Test accuracy: ', str(np.round(score[1],4)))
    
    #Posterior predictions
    y_pred = drop_model.predict(X_test)
    dropout_post_predictions.append(y_pred)
    
    #Predictions & uncertainty for test points
    ood_prob = drop_model.predict(np.array(test_points))
    dropout_ood_probs.append(ood_prob)
    
    pred2 = drop_model.predict(grid_2d)[:,0].flatten()
    grid_preds.append(pred2)
# Out:
# Iteration: 1 Random p: 0.12 Test accuracy:  0.992
# Iteration: 2 Random p: 0.96 Test accuracy:  0.991
# Iteration: 3 Random p: 0.08 Test accuracy:  0.992
# Iteration: 4 Random p: 0.52 Test accuracy:  0.992
# Iteration: 5 Random p: 0.36 Test accuracy:  0.989
# Iteration: 6 Random p: 0.16 Test accuracy:  0.987
# Iteration: 7 Random p: 0.85 Test accuracy:  0.992
# Iteration: 8 Random p: 0.77 Test accuracy:  0.987
# Iteration: 9 Random p: 0.81 Test accuracy:  0.986
# Iteration: 10 Random p: 0.63 Test accuracy:  0.988
# Iteration: 11 Random p: 0.36 Test accuracy:  0.99
# Iteration: 12 Random p: 0.39 Test accuracy:  0.993
# Iteration: 13 Random p: 0.57 Test accuracy:  0.992
# Iteration: 14 Random p: 0.37 Test accuracy:  0.99
# Iteration: 15 Random p: 0.61 Test accuracy:  0.987
# Iteration: 16 Random p: 0.57 Test accuracy:  0.991
# Iteration: 17 Random p: 0.39 Test accuracy:  0.994
# Iteration: 18 Random p: 0.92 Test accuracy:  0.991
# Iteration: 19 Random p: 0.61 Test accuracy:  0.989
# Iteration: 20 Random p: 0.72 Test accuracy:  0.986
# Iteration: 21 Random p: 0.15 Test accuracy:  0.991
# Iteration: 22 Random p: 0.89 Test accuracy:  0.991
# Iteration: 23 Random p: 0.37 Test accuracy:  0.989
# Iteration: 24 Random p: 0.49 Test accuracy:  0.991
# Iteration: 25 Random p: 0.15 Test accuracy:  0.99
# Iteration: 26 Random p: 0.25 Test accuracy:  0.988
# Iteration: 27 Random p: 0.07 Test accuracy:  0.991
# Iteration: 28 Random p: 0.2 Test accuracy:  0.989
# Iteration: 29 Random p: 0.12 Test accuracy:  0.991
# Iteration: 30 Random p: 0.4 Test accuracy:  0.992

# %%
df = pd.DataFrame(np.array(drop_weights))

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0.95, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian dropout weights ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cos_similarity_plot_dropout.png".format(TOY_DATA_TYPE))

# %%
dropout_posterior_mean_preds = np.mean(np.array(dropout_post_predictions),axis=0)
dropout_posterior_mean_preds.shape
# Out:
# (1000, 1)

# %%
dropout_pred_test_labels = (dropout_posterior_mean_preds > 0.5).astype(np.int) 
dropout_acc_score = accuracy_score(Y_test, dropout_pred_test_labels)
print("Bayesian Dropout posterior predictive mean accuracy score for test data: ", dropout_acc_score)
# Out:
# Bayesian Dropout posterior predictive mean accuracy score for test data:  0.994

# %%
drop_ood_variance = np.std(np.array(dropout_ood_probs),axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], drop_ood_variance[i][0]))
# Out:
# uncertainty for test point: (0, 0) : 1.2795611326055223e-07
# uncertainty for test point: (0, 2) : 2.2459545334641007e-10
# uncertainty for test point: (0, -2) : 3.5309727763888077e-07
# uncertainty for test point: (2, 0) : 2.751126615407884e-08
# uncertainty for test point: (-2, 0) : 5.366396216288649e-10
# uncertainty for test point: (-1, 0) : 5.36740074608133e-08
# uncertainty for test point: (-0.75, 0) : 0.0073197707533836365
# uncertainty for test point: (-0.5, 0) : 8.534991025044292e-07
# uncertainty for test point: (1, 0) : 1.8905119532064418e-06
# uncertainty for test point: (0.75, 0) : 0.05603266507387161
# uncertainty for test point: (0.5, 0) : 2.511500269974931e-07
# uncertainty for test point: (0, 1) : 2.7402941782384005e-07
# uncertainty for test point: (0, 0.75) : 0.0334729328751564
# uncertainty for test point: (0, 0.5) : 5.023391054237436e-07
# uncertainty for test point: (0, -1) : 2.3371362658508588e-06
# uncertainty for test point: (0, -0.75) : 0.04792573302984238
# uncertainty for test point: (0, -0.5) : 4.1764985780901043e-07

# %%
dropout_pred_test_labels.shape
# Out:
# (1000, 1)

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.mean(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for dropout model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_dropout.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.std(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for dropout model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_dropout.png".format(TOY_DATA_TYPE))

# %%
tsne = TSNE(n_components=2)
ens_test_probs_pca = tsne.fit_transform(np.array(ens_test_probs).reshape(30, 1000))


plt.scatter(ens_test_probs_pca[:,0], ens_test_probs_pca[:,1])
plt.title("TSNE plot of predictions for dropout model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_dropout.png".format(TOY_DATA_TYPE))

# %% [markdown]
# ## Random Subspace Sampling

# %%
models = []
random_weights= []
# iterate over different samples
for i in range(bayes_iters):
    # make a new NN with the same layout
    model2 = get_model(mc=False)
    # add random vector to presaved model weights
    model2.load_weights('initial_model_weights.h5')
    #Added scale to regularize randomness
    weights = [model2.get_weights()[j] + np.random.normal(size = model2.get_weights()[j].shape, scale=0.2) for j in range(len(model.get_weights()))]
    model2.set_weights(weights)
    #Get Dense model weights
    weights = model2.get_weights()
    flat_weight_array = np.array([])
    for weight in weights:
        flat_weight_array = np.concatenate((flat_weight_array, weight.flatten()))
    random_weights.append(flat_weight_array)
    models.append(model2)

# %%
random_post_predictions = []
grid_preds = []
random_ood_probs = []

for model in models: 
    y_pred = model.predict(X_test)
    random_post_predictions.append(y_pred)
    pred2 = model.predict(grid_2d)[:,0].flatten()
    grid_preds.append(pred2)
    #Predictions & uncertainty for test points
    ood_prob = model.predict(np.array(test_points))
    random_ood_probs.append(ood_prob)
    
random_posterior_mean_preds = np.mean(np.array(random_post_predictions),axis=0)
random_pred_test_labels = (random_posterior_mean_preds > 0.5).astype(np.int) 
random_acc_score = accuracy_score(Y_test, random_pred_test_labels)
print("Random subspace posterior predictive Test set mean accuracy score for test data: ", random_acc_score)
# Out:
# Random subspace posterior predictive Test set mean accuracy score for test data:  0.993

# %%
random_ood_variance = np.std(np.array(random_ood_probs),axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], random_ood_variance[i][0]))
# Out:
# uncertainty for test point: (0, 0) : 3.324834779050434e-06
# uncertainty for test point: (0, 2) : 1.7316812872536502e-08
# uncertainty for test point: (0, -2) : 2.5334129531984217e-05
# uncertainty for test point: (2, 0) : 4.045286004838999e-06
# uncertainty for test point: (-2, 0) : 9.347048290919702e-08
# uncertainty for test point: (-1, 0) : 0.0033703334629535675
# uncertainty for test point: (-0.75, 0) : 0.12774771451950073
# uncertainty for test point: (-0.5, 0) : 0.00041797192534431815
# uncertainty for test point: (1, 0) : 0.0020826507825404406
# uncertainty for test point: (0.75, 0) : 0.14826273918151855
# uncertainty for test point: (0.5, 0) : 0.018743930384516716
# uncertainty for test point: (0, 1) : 0.0026719067245721817
# uncertainty for test point: (0, 0.75) : 0.12152142077684402
# uncertainty for test point: (0, 0.5) : 0.002413808135315776
# uncertainty for test point: (0, -1) : 0.02399720437824726
# uncertainty for test point: (0, -0.75) : 0.13370423018932343
# uncertainty for test point: (0, -0.5) : 0.0014231096720322967

# %%
df = pd.DataFrame(np.array(random_weights))

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian random sampling ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cosine_similarity_plot_random.png".format(TOY_DATA_TYPE))

# %%
fig, ax = plt.subplots(figsize=(16, 9))
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
contour = ax.contourf(grid[0], grid[1], np.mean(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for random sampling model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_random.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.std(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for random sampling model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_posterior_predictive_plot_random.png".format(TOY_DATA_TYPE))

# %%
tsne = TSNE(n_components=2)
ens_test_probs_pca = tsne.fit_transform(np.array(ens_test_probs).reshape(30, 1000))


plt.scatter(ens_test_probs_pca[:,0], ens_test_probs_pca[:,1])
plt.title("TSNE plot of predictions for random sampling model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_random.png".format(TOY_DATA_TYPE))

# %% [markdown]
# ### HMC

# %%
def construct_nn(ann_input, ann_output):
    n_hidden1 = 64
    n_hidden2 = 8

    # Initialize random weights between each layer
    model = get_model(mc=False)
    model.load_weights('initial_model_weights.h5')
    ws = model.get_weights()
    init_1 = ws[0].astype(floatX)
    init_2 = ws[2].astype(floatX)
    init_out = ws[4].flatten().astype(floatX)
    init_b1 = ws[1].astype(floatX)
    init_b2 = ws[3].astype(floatX)
    init_bout = ws[5].astype(floatX)

    with pm.Model() as neural_network:
        # Trick: Turn inputs and outputs into shared variables using the data container pm.Data
        # It's still the same thing, but we can later change the values of the shared variable
        # (to switch in the test-data later) and pymc3 will just use the new data.
        # Kind-of like a pointer we can redirect.
        # For more info, see: http://deeplearning.net/software/theano/library/compile/shared.html
        ann_input = pm.Data('ann_input', ann_input)
        ann_output = pm.Data('ann_output', ann_output)

        # Weights from input to hidden layer
        weights_in_1 = pm.Normal('w_in_1', 0, sigma=1,
                                 shape=(X.shape[1], n_hidden1),
                                 testval=init_1)
        biases_in_1 = pm.Normal('b_in_1', 0, sigma=1,
                                 shape=(n_hidden1,),
                                 testval=init_b1)

        # Weights from 1st to 2nd layer
        weights_1_2 = pm.Normal('w_1_2', 0, sigma=1,
                                shape=(n_hidden1, n_hidden2),
                                testval=init_2)
        biases_1_2 = pm.Normal('b_1_2', 0, sigma=1,
                                 shape=(n_hidden2,),
                                 testval=init_b2)

        # Weights from hidden layer to output
        weights_2_out = pm.Normal('w_2_out', 0, sigma=1,
                                  shape=(n_hidden2,),
                                  testval=init_out)
        biases_2_out = pm.Normal('b_3_out', 0, sigma=1,
                                 shape=(1,),
                                 testval=init_bout)

        # Build neural-network using tanh activation function
        act_1 = pm.math.tanh(pm.math.dot(ann_input,
                                         weights_in_1)+biases_in_1)
        act_2 = pm.math.tanh(pm.math.dot(act_1,
                                         weights_1_2)+biases_1_2)
        act_out = pm.math.sigmoid(pm.math.dot(act_2,
                                              weights_2_out)+biases_2_out)

        # Binary classification -> Bernoulli likelihood
        out = pm.Bernoulli('out',
                           act_out,
                           observed=ann_output,
                           total_size=Y_train.shape[0] # IMPORTANT for minibatches
                          )
    return neural_network

neural_network = construct_nn(X_train, Y_train)

# %%
from pymc3.theanof import set_tt_rng, MRG_RandomStreams
set_tt_rng(MRG_RandomStreams(42))

# %%
with neural_network:
    steps = pm.NUTS()
    #use the specify sampler to sample from the posterior of the model
    trace = pm.sample(5000, step=steps, tune=1000, chains=1)
# Out:
# Sequential sampling (1 chains in 1 job)
# NUTS: [b_3_out, w_2_out, b_1_2, w_1_2, b_in_1, w_in_1]
# Sampling chain 0, 32 divergences: 100%|██████████| 6000/6000 [1:12:47<00:00,  1.37it/s]
# There were 32 divergences after tuning. Increase `target_accept` or reparameterize.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
pm.set_data(new_data={'ann_input': X_test, 'ann_output': Y_test}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)

# %%
pred = ppc["out"].mean(axis=0) > 0.5

# %%
print('Test Set Accuracy = {}%'.format((Y_test == pred).mean() * 100))
# Out:
# Test Set Accuracy = 99.2%

# %%
pm.set_data(new_data={'ann_input': np.array(test_points), 'ann_output': np.ones(len(test_points), dtype=np.int8)}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)
ood_variance = np.std(ppc["out"],axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], ood_variance[i]))
# Out:
# uncertainty for test point: (0, 0) : 0.0
# uncertainty for test point: (0, 2) : 0.017676000000000032
# uncertainty for test point: (0, -2) : 0.015744000000000067
# uncertainty for test point: (2, 0) : 0.011855999999999998
# uncertainty for test point: (-2, 0) : 0.01185599999999995
# uncertainty for test point: (-1, 0) : 0.003984000000000002
# uncertainty for test point: (-0.75, 0) : 0.20919600000000052
# uncertainty for test point: (-0.5, 0) : 0.003984000000000006
# uncertainty for test point: (1, 0) : 0.0019960000000000025
# uncertainty for test point: (0.75, 0) : 0.24989999999999812
# uncertainty for test point: (0.5, 0) : 0.0
# uncertainty for test point: (0, 1) : 0.0019960000000000004
# uncertainty for test point: (0, 0.75) : 0.24615600000000082
# uncertainty for test point: (0, 0.5) : 0.003984000000000011
# uncertainty for test point: (0, -1) : 0.0039840000000000144
# uncertainty for test point: (0, -0.75) : 0.24359999999999976
# uncertainty for test point: (0, -0.5) : 0.0

# %%
pm.set_data(new_data={'ann_input': grid_2d, 'ann_output': dummy_out}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc["out"].mean(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for HMC model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_hmc.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc["out"].std(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for HMC model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_hmc.png".format(TOY_DATA_TYPE))

# %%
pm.set_data(new_data={'ann_input': grid_2d, 'ann_output': dummy_out}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)["out"]
tsne = TSNE(n_components=2)
ppc_pca = tsne.fit_transform(ppc)


plt.plot(ppc_pca[:,0], ppc_pca[:,1], linestyle = "", marker = "o")
plt.title("TSNE plot of predictions for HMC model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_hmc.png".format(TOY_DATA_TYPE))

# %%
combined = trace["w_in_1"].reshape(-1, 64*2)
combined = np.concatenate((combined, trace["w_1_2"].reshape(-1, 64*8)), axis=1)
combined = np.concatenate((combined, trace["w_2_out"]), axis=1)
combined = np.concatenate((combined, trace["b_in_1"]), axis=1)
combined = np.concatenate((combined, trace["b_1_2"]), axis=1)
combined = np.concatenate((combined, trace["b_3_out"]), axis=1)

df = pd.DataFrame(np.array(combined)[-30:])

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian HMC model ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cos_similarity_plot_hmc.png".format(TOY_DATA_TYPE))

# %% [markdown]
# ### ADVI

# %%
neural_network = construct_nn(X_train, Y_train)

# %%
with neural_network:
    steps = pm.ADVI()
    #use the specify sampler to sample from the posterior of the model
    approx = pm.fit(n=30000, method=steps)
# Out:
# Average Loss = 621.2: 100%|██████████| 30000/30000 [00:54<00:00, 548.50it/s]
# Finished [100%]: Average Loss = 621.18

# %%
# create symbolic input
x_sym = T.matrix('X_test')
# symbolic number of samples is supported, we build vectorized posterior on the fly
n_sym = T.iscalar('n')
# Do not forget test_values or set theano.config.compute_test_value = 'off'
x_sym.tag.test_value = np.empty_like(X_test)
n_sym.tag.test_value = X_test.shape[1]
_sample_proba = approx.sample_node(neural_network.out.distribution.p,
                                   size=n_sym,
                                   more_replacements={neural_network['ann_input']: x_sym})
# Efficient vectorized form of sampling is used
sample_proba = theano.function([x_sym, n_sym], _sample_proba)
pred = (sample_proba(X_test, 500).mean(0) > 0.5) * 1
print('Test Set Accuracy = {}%'.format((Y_test == pred).mean() * 100))
# Out:
# Test Set Accuracy = 98.8%

# %%
ppc = sample_proba(test_points ,500)
ood_variance = np.std(ppc,axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], ood_variance[i]))
# Out:
# uncertainty for test point: (0, 0) : 0.002117849886570223
# uncertainty for test point: (0, 2) : 0.014314900759647024
# uncertainty for test point: (0, -2) : 0.03493044483557796
# uncertainty for test point: (2, 0) : 0.046530450371014026
# uncertainty for test point: (-2, 0) : 0.01588447472301444
# uncertainty for test point: (-1, 0) : 0.03964908173909124
# uncertainty for test point: (-0.75, 0) : 0.1057811263936828
# uncertainty for test point: (-0.5, 0) : 0.037351702407600315
# uncertainty for test point: (1, 0) : 0.046722073509095116
# uncertainty for test point: (0.75, 0) : 0.09013649005760407
# uncertainty for test point: (0.5, 0) : 0.03469856097728695
# uncertainty for test point: (0, 1) : 0.03980792391567471
# uncertainty for test point: (0, 0.75) : 0.10895822628342973
# uncertainty for test point: (0, 0.5) : 0.03824592723484374
# uncertainty for test point: (0, -1) : 0.05210746597542934
# uncertainty for test point: (0, -0.75) : 0.09016116211775328
# uncertainty for test point: (0, -0.5) : 0.03436990414876605

# %%
# populate grid with average predictions
ppc = sample_proba(grid_2d ,500)
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc.mean(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for ADVI model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_advi.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc.std(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for ADVI model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_advi.png".format(TOY_DATA_TYPE))

# %%
ppc = sample_proba(X_test ,500)
tsne = TSNE(n_components=2)
ppc_pca = tsne.fit_transform(ppc)


plt.plot(ppc_pca[:,0], ppc_pca[:,1], linestyle = "", marker = "o")
plt.title("TSNE plot of predictions for ADVI model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_advi.png".format(TOY_DATA_TYPE))

# %%
combined = trace["w_in_1"].reshape(-1, 64*2)
combined = np.concatenate((combined, trace["w_1_2"].reshape(-1, 64*8)), axis=1)
combined = np.concatenate((combined, trace["w_2_out"]), axis=1)
combined = np.concatenate((combined, trace["b_in_1"]), axis=1)
combined = np.concatenate((combined, trace["b_1_2"]), axis=1)
combined = np.concatenate((combined, trace["b_3_out"]), axis=1)

df = pd.DataFrame(np.array(combined)[-30:])

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian ADVI model ({} data) ".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cosine_similarity_plot_advi.png".format(TOY_DATA_TYPE))
