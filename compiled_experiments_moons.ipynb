# %% [markdown]
# # AM 207 - Deep Ensembles: A Loss Landscape Perspective
#
# ### Moons Toy Dataset Experimentation Notebook

# %% [markdown]
# #### Project Team: Emre Erdem, Carter Nakamoto, Anita Mahinpei

# %% [markdown]
# ## Table of Content
#
# 1. [Toy Dataset Creation](#toy-data-creation)
# 2. [Initial Neural Network Training](#initial-nn-training)
# 3. [Deep Ensemble with Random Initialization](#deep-ensemble)
# 4. [Dropout Subspace Sampling](#dropout)
# 5. [Random Subspace Sampling](#random)
# 6. [HMC](#hmc)
# 7. [ADVI](#advi)

# %%
import tensorflow as tf
#from keras.datasets import cifar10
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import Input
#from keras.layers import Conv2D, MaxPooling2D
#from keras import backend as K

import numpy as np
import pandas as pd
import pymc3 as pm

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.preprocessing import scale
from sklearn.datasets import make_moons, make_circles, make_blobs
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline
import seaborn as sns 

import theano
import theano.tensor as T
from warnings import filterwarnings

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.1

# %%
# %config InlineBackend.figure_format = 'retina'
theano.config.gcc.cxxflags = "-Wno-c++11-narrowing"
floatX = theano.config.floatX
filterwarnings('ignore')
sns.set_style('white')

# %% [markdown]
# <a id='toy-data-creation'></a>
# ## 1. Toy Dataset Creation

# %%
TOY_DATA_TYPE = "moons"

# Generate a toy dataset for classification
def generate_toy_data():
    if TOY_DATA_TYPE == "moons":
        return make_moons(noise=0.2, random_state=0, n_samples=2000)
    elif TOY_DATA_TYPE == "circles":
        return make_circles(noise=0.1, random_state=0, n_samples=2000, factor=0.5)
    elif TOY_DATA_TYPE == "blobs":
        return make_blobs(cluster_std=0.8, random_state=0, n_samples=2000, centers=np.array([[-1,-1], [1, 1]]))

X, Y = generate_toy_data()
X = X.astype(floatX)
Y = Y.astype(floatX)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.5)

# Define test data points
def generate_test_points(): 
    if TOY_DATA_TYPE == "moons":
        return [(0.5, -0.4), (0.5, 0.8), (0.5, 0.25), (-0.8, 0.5), (1.7, -0.3), (-1.5, -3), 
                (-1.5, 3), (3, -3), (3, 3)]
    elif TOY_DATA_TYPE == "circles":
        return [(0, 0), (0, 2), (0, -2), (2, 0), (-2, 0), (-1, 0), (-0.75, 0), (-0.5, 0),
               (1, 0), (0.75, 0), (0.5, 0), (0, 1), (0, 0.75), (0, 0.5), (0, -1), (0, -0.75), 
                (0, -0.5)]
    elif TOY_DATA_TYPE == "blobs":
        return [(-5, -5), (-5, 3.5), (5, 5), (5, -3.5), (-1, 1), (-1, -1.5), (1, 1.5)]

test_points = generate_test_points()

# %%
# Visualize our test data points
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
ax.scatter(X[Y == 1, 0], X[Y == 1, 1], alpha=0.3, color='red', label='class 1')
ax.scatter(X[Y == 0, 0], X[Y == 0, 1], alpha=0.3, color='blue', label='class 0')
for i in range(len(test_points)):
    pt = test_points[i]
    if i == 0:
        ax.scatter(pt[0], pt[1], alpha=1., s=50, color='black', label='test data')
    else:
        ax.scatter(pt[0], pt[1], alpha=1., s=50, color='black')
ax.set_xlabel('x_1')
ax.set_ylabel('x_2')
ax.set_title('{} classification data with test data points'.format(TOY_DATA_TYPE))
ax.legend(loc='best')
plt.savefig("{}_data_plot.png".format(TOY_DATA_TYPE))

# %% [markdown]
# <a id='initial-nn-training'></a>
# ## 2. Initial Neural Network Training

# %%
batch_size = 256
num_classes = 2
epochs = 1000

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.5, random_state=42)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
print('x_train shape:', X_train.shape)
print('x_test shape:', X_test.shape)
# Out:
# x_train shape: (1000, 2)
# x_test shape: (1000, 2)

# %%
Y_train.shape
# Out:
# (1000,)

# %%
input_shape = X_train.shape[1]
input_shape
# Out:
# 2

# %%
def get_dropout(input_tensor, p=0.5, mc=False):
    if mc:
        return Dropout(p)(input_tensor)
    else:
        return input_tensor

def get_model(mc=False, p=0.5, act="tanh"):
    if TOY_DATA_TYPE == "blobs" or TOY_DATA_TYPE == "moons" or TOY_DATA_TYPE == "circles":
        inp = Input(shape=(input_shape,))
        x = Dense(64, activation=act)(inp)
        x = get_dropout(x, p=p, mc=mc)
        x = Dense(8, activation=act)(x)
        x = get_dropout(x, p=p, mc=mc)
        out = Dense(1, activation='sigmoid')(x)

        model = Model(inputs=inp, outputs=out)

        model.compile(loss=tf.keras.losses.binary_crossentropy,
                      optimizer=tf.keras.optimizers.Adam(),
                      metrics=['accuracy'])
        return model

# %%
base_model = get_model(mc=False)

# %%
base_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                192
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 520
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 721
# Trainable params: 721
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min', patience=20)
history = base_model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=[es],
                    validation_data=(X_test, Y_test))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.8262 - accuracy: 0.1580 - val_loss: 0.7851 - val_accuracy: 0.1370
# Epoch 2/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7602 - accuracy: 0.1640 - val_loss: 0.7215 - val_accuracy: 0.2600
# Epoch 3/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7003 - accuracy: 0.3730 - val_loss: 0.6660 - val_accuracy: 0.5700
# Epoch 4/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6496 - accuracy: 0.6230 - val_loss: 0.6180 - val_accuracy: 0.6960
# Epoch 5/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6060 - accuracy: 0.7000 - val_loss: 0.5769 - val_accuracy: 0.7430
# Epoch 6/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5688 - accuracy: 0.7370 - val_loss: 0.5421 - val_accuracy: 0.7610
# Epoch 7/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5374 - accuracy: 0.7620 - val_loss: 0.5128 - val_accuracy: 0.7720
# Epoch 8/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5101 - accuracy: 0.7690 - val_loss: 0.4881 - val_accuracy: 0.7810
# Epoch 9/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4872 - accuracy: 0.7780 - val_loss: 0.4670 - val_accuracy: 0.7870
# Epoch 10/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4671 - accuracy: 0.7890 - val_loss: 0.4490 - val_accuracy: 0.7970
# Epoch 11/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4498 - accuracy: 0.7950 - val_loss: 0.4332 - val_accuracy: 0.8020
# Epoch 12/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4349 - accuracy: 0.8020 - val_loss: 0.4193 - val_accuracy: 0.8070
# Epoch 13/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4221 - accuracy: 0.8070 - val_loss: 0.4068 - val_accuracy: 0.8110
# Epoch 14/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4100 - accuracy: 0.8140 - val_loss: 0.3959 - val_accuracy: 0.8150
# Epoch 15/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3995 - accuracy: 0.8190 - val_loss: 0.3861 - val_accuracy: 0.8210
# Epoch 16/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3898 - accuracy: 0.8230 - val_loss: 0.3775 - val_accuracy: 0.8260
# Epoch 17/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3813 - accuracy: 0.8270 - val_loss: 0.3696 - val_accuracy: 0.8300
# Epoch 18/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3735 - accuracy: 0.8280 - val_loss: 0.3625 - val_accuracy: 0.8340
# Epoch 19/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3667 - accuracy: 0.8300 - val_loss: 0.3561 - val_accuracy: 0.8370
# Epoch 20/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3602 - accuracy: 0.8310 - val_loss: 0.3502 - val_accuracy: 0.8400
# Epoch 21/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3544 - accuracy: 0.8370 - val_loss: 0.3449 - val_accuracy: 0.8420
# Epoch 22/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3492 - accuracy: 0.8390 - val_loss: 0.3402 - val_accuracy: 0.8450
# Epoch 23/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3443 - accuracy: 0.8410 - val_loss: 0.3358 - val_accuracy: 0.8500
# Epoch 24/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3401 - accuracy: 0.8430 - val_loss: 0.3320 - val_accuracy: 0.8530
# Epoch 25/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3360 - accuracy: 0.8430 - val_loss: 0.3283 - val_accuracy: 0.8570
# Epoch 26/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3323 - accuracy: 0.8450 - val_loss: 0.3250 - val_accuracy: 0.8580
# Epoch 27/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3292 - accuracy: 0.8480 - val_loss: 0.3220 - val_accuracy: 0.8600
# Epoch 28/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3262 - accuracy: 0.8530 - val_loss: 0.3192 - val_accuracy: 0.8630
# Epoch 29/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3235 - accuracy: 0.8570 - val_loss: 0.3169 - val_accuracy: 0.8640
# Epoch 30/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3211 - accuracy: 0.8570 - val_loss: 0.3149 - val_accuracy: 0.8640
# Epoch 31/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3188 - accuracy: 0.8590 - val_loss: 0.3128 - val_accuracy: 0.8660
# Epoch 32/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3168 - accuracy: 0.8610 - val_loss: 0.3111 - val_accuracy: 0.8660
# Epoch 33/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3152 - accuracy: 0.8630 - val_loss: 0.3094 - val_accuracy: 0.8670
# Epoch 34/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3134 - accuracy: 0.8640 - val_loss: 0.3080 - val_accuracy: 0.8670
# Epoch 35/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3121 - accuracy: 0.8640 - val_loss: 0.3064 - val_accuracy: 0.8660
# Epoch 36/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3107 - accuracy: 0.8640 - val_loss: 0.3054 - val_accuracy: 0.8660
# Epoch 37/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3096 - accuracy: 0.8630 - val_loss: 0.3045 - val_accuracy: 0.8680
# Epoch 38/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3085 - accuracy: 0.8660 - val_loss: 0.3036 - val_accuracy: 0.8670
# Epoch 39/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3075 - accuracy: 0.8660 - val_loss: 0.3027 - val_accuracy: 0.8680
# Epoch 40/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.8660 - val_loss: 0.3019 - val_accuracy: 0.8680
# Epoch 41/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3061 - accuracy: 0.8660 - val_loss: 0.3011 - val_accuracy: 0.8710
# Epoch 42/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3054 - accuracy: 0.8680 - val_loss: 0.3006 - val_accuracy: 0.8710
# Epoch 43/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3047 - accuracy: 0.8670 - val_loss: 0.3001 - val_accuracy: 0.8710
# Epoch 44/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3042 - accuracy: 0.8670 - val_loss: 0.2996 - val_accuracy: 0.8710
# Epoch 45/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3036 - accuracy: 0.8680 - val_loss: 0.2992 - val_accuracy: 0.8720
# Epoch 46/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3033 - accuracy: 0.8670 - val_loss: 0.2990 - val_accuracy: 0.8710
# Epoch 47/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3029 - accuracy: 0.8660 - val_loss: 0.2985 - val_accuracy: 0.8710
# Epoch 48/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3025 - accuracy: 0.8660 - val_loss: 0.2982 - val_accuracy: 0.8710
# Epoch 49/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3022 - accuracy: 0.8660 - val_loss: 0.2980 - val_accuracy: 0.8710
# Epoch 50/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3020 - accuracy: 0.8660 - val_loss: 0.2979 - val_accuracy: 0.8710
# Epoch 51/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3017 - accuracy: 0.8660 - val_loss: 0.2978 - val_accuracy: 0.8710
# Epoch 52/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3016 - accuracy: 0.8670 - val_loss: 0.2974 - val_accuracy: 0.8710
# Epoch 53/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3013 - accuracy: 0.8670 - val_loss: 0.2973 - val_accuracy: 0.8710
# Epoch 54/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3012 - accuracy: 0.8670 - val_loss: 0.2969 - val_accuracy: 0.8710
# Epoch 55/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3010 - accuracy: 0.8670 - val_loss: 0.2969 - val_accuracy: 0.8710
# Epoch 56/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3009 - accuracy: 0.8670 - val_loss: 0.2967 - val_accuracy: 0.8710
# Epoch 57/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3007 - accuracy: 0.8670 - val_loss: 0.2967 - val_accuracy: 0.8710
# Epoch 58/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3006 - accuracy: 0.8670 - val_loss: 0.2966 - val_accuracy: 0.8710
# Epoch 59/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3006 - accuracy: 0.8670 - val_loss: 0.2964 - val_accuracy: 0.8710
# Epoch 60/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3004 - accuracy: 0.8670 - val_loss: 0.2965 - val_accuracy: 0.8710
# Epoch 61/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3003 - accuracy: 0.8670 - val_loss: 0.2965 - val_accuracy: 0.8710
# Epoch 62/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3003 - accuracy: 0.8670 - val_loss: 0.2965 - val_accuracy: 0.8710
# Epoch 63/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3002 - accuracy: 0.8670 - val_loss: 0.2962 - val_accuracy: 0.8710
# Epoch 64/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3001 - accuracy: 0.8670 - val_loss: 0.2963 - val_accuracy: 0.8710
# Epoch 65/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3000 - accuracy: 0.8670 - val_loss: 0.2960 - val_accuracy: 0.8710
# Epoch 66/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2999 - accuracy: 0.8670 - val_loss: 0.2959 - val_accuracy: 0.8710
# Epoch 67/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3000 - accuracy: 0.8670 - val_loss: 0.2956 - val_accuracy: 0.8710
# Epoch 68/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3001 - accuracy: 0.8670 - val_loss: 0.2960 - val_accuracy: 0.8700
# Epoch 69/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2998 - accuracy: 0.8670 - val_loss: 0.2961 - val_accuracy: 0.8700
# Epoch 70/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2997 - accuracy: 0.8670 - val_loss: 0.2960 - val_accuracy: 0.8700
# Epoch 71/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2996 - accuracy: 0.8670 - val_loss: 0.2958 - val_accuracy: 0.8700
# Epoch 72/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2996 - accuracy: 0.8670 - val_loss: 0.2955 - val_accuracy: 0.8710
# Epoch 73/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2996 - accuracy: 0.8670 - val_loss: 0.2955 - val_accuracy: 0.8710
# Epoch 74/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2996 - accuracy: 0.8670 - val_loss: 0.2953 - val_accuracy: 0.8710
# Epoch 75/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2996 - accuracy: 0.8670 - val_loss: 0.2956 - val_accuracy: 0.8700
# Epoch 76/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2994 - accuracy: 0.8670 - val_loss: 0.2955 - val_accuracy: 0.8710
# Epoch 77/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2994 - accuracy: 0.8670 - val_loss: 0.2954 - val_accuracy: 0.8710
# Epoch 78/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2995 - accuracy: 0.8670 - val_loss: 0.2956 - val_accuracy: 0.8700
# Epoch 79/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2995 - accuracy: 0.8670 - val_loss: 0.2953 - val_accuracy: 0.8710
# Epoch 80/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2993 - accuracy: 0.8670 - val_loss: 0.2954 - val_accuracy: 0.8710
# Epoch 81/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2993 - accuracy: 0.8670 - val_loss: 0.2957 - val_accuracy: 0.8690
# Epoch 82/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2992 - accuracy: 0.8670 - val_loss: 0.2955 - val_accuracy: 0.8690
# Epoch 83/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2994 - accuracy: 0.8670 - val_loss: 0.2951 - val_accuracy: 0.8700
# Epoch 84/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2992 - accuracy: 0.8670 - val_loss: 0.2950 - val_accuracy: 0.8700
# Epoch 85/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2991 - accuracy: 0.8670 - val_loss: 0.2953 - val_accuracy: 0.8700
# Epoch 86/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2992 - accuracy: 0.8670 - val_loss: 0.2956 - val_accuracy: 0.8690
# Epoch 87/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2990 - accuracy: 0.8670 - val_loss: 0.2955 - val_accuracy: 0.8690
# Epoch 88/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2990 - accuracy: 0.8670 - val_loss: 0.2954 - val_accuracy: 0.8690
# Epoch 89/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2990 - accuracy: 0.8670 - val_loss: 0.2950 - val_accuracy: 0.8700
# Epoch 90/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2990 - accuracy: 0.8670 - val_loss: 0.2948 - val_accuracy: 0.8710
# Epoch 91/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2990 - accuracy: 0.8670 - val_loss: 0.2951 - val_accuracy: 0.8700
# Epoch 92/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2990 - accuracy: 0.8670 - val_loss: 0.2952 - val_accuracy: 0.8700
# Epoch 93/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2988 - accuracy: 0.8670 - val_loss: 0.2950 - val_accuracy: 0.8700
# Epoch 94/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2987 - accuracy: 0.8670 - val_loss: 0.2948 - val_accuracy: 0.8710
# Epoch 95/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2987 - accuracy: 0.8670 - val_loss: 0.2946 - val_accuracy: 0.8700
# Epoch 96/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2988 - accuracy: 0.8670 - val_loss: 0.2946 - val_accuracy: 0.8700
# Epoch 97/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2988 - accuracy: 0.8670 - val_loss: 0.2949 - val_accuracy: 0.8700
# Epoch 98/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2986 - accuracy: 0.8670 - val_loss: 0.2947 - val_accuracy: 0.8700
# Epoch 99/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2986 - accuracy: 0.8670 - val_loss: 0.2945 - val_accuracy: 0.8700
# Epoch 100/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2986 - accuracy: 0.8670 - val_loss: 0.2945 - val_accuracy: 0.8700
# Epoch 101/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2985 - accuracy: 0.8670 - val_loss: 0.2947 - val_accuracy: 0.8700
# Epoch 102/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2985 - accuracy: 0.8670 - val_loss: 0.2946 - val_accuracy: 0.8700
# Epoch 103/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2984 - accuracy: 0.8670 - val_loss: 0.2946 - val_accuracy: 0.8700
# Epoch 104/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2984 - accuracy: 0.8670 - val_loss: 0.2948 - val_accuracy: 0.8690
# Epoch 105/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2984 - accuracy: 0.8670 - val_loss: 0.2949 - val_accuracy: 0.8690
# Epoch 106/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2983 - accuracy: 0.8670 - val_loss: 0.2947 - val_accuracy: 0.8690
# Epoch 107/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2983 - accuracy: 0.8670 - val_loss: 0.2947 - val_accuracy: 0.8690
# Epoch 108/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2983 - accuracy: 0.8670 - val_loss: 0.2943 - val_accuracy: 0.8700
# Epoch 109/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2983 - accuracy: 0.8670 - val_loss: 0.2941 - val_accuracy: 0.8700
# Epoch 110/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2982 - accuracy: 0.8670 - val_loss: 0.2942 - val_accuracy: 0.8700
# Epoch 111/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2982 - accuracy: 0.8670 - val_loss: 0.2945 - val_accuracy: 0.8690
# Epoch 112/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2982 - accuracy: 0.8670 - val_loss: 0.2946 - val_accuracy: 0.8700
# Epoch 113/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2983 - accuracy: 0.8670 - val_loss: 0.2942 - val_accuracy: 0.8700
# Epoch 114/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2981 - accuracy: 0.8670 - val_loss: 0.2941 - val_accuracy: 0.8700
# Epoch 115/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2981 - accuracy: 0.8670 - val_loss: 0.2945 - val_accuracy: 0.8690
# Epoch 116/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2982 - accuracy: 0.8670 - val_loss: 0.2942 - val_accuracy: 0.8700
# Epoch 117/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2980 - accuracy: 0.8670 - val_loss: 0.2944 - val_accuracy: 0.8700
# Epoch 118/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2979 - accuracy: 0.8670 - val_loss: 0.2943 - val_accuracy: 0.8700
# Epoch 119/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2979 - accuracy: 0.8670 - val_loss: 0.2941 - val_accuracy: 0.8700
# Epoch 120/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2978 - accuracy: 0.8670 - val_loss: 0.2939 - val_accuracy: 0.8700
# Epoch 121/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2978 - accuracy: 0.8670 - val_loss: 0.2940 - val_accuracy: 0.8690
# Epoch 122/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2978 - accuracy: 0.8670 - val_loss: 0.2942 - val_accuracy: 0.8700
# Epoch 123/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2977 - accuracy: 0.8670 - val_loss: 0.2941 - val_accuracy: 0.8700
# Epoch 124/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2977 - accuracy: 0.8670 - val_loss: 0.2939 - val_accuracy: 0.8700
# Epoch 125/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2977 - accuracy: 0.8670 - val_loss: 0.2937 - val_accuracy: 0.8700
# Epoch 126/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2976 - accuracy: 0.8670 - val_loss: 0.2938 - val_accuracy: 0.8690
# Epoch 127/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2976 - accuracy: 0.8670 - val_loss: 0.2940 - val_accuracy: 0.8690
# Epoch 128/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2976 - accuracy: 0.8670 - val_loss: 0.2937 - val_accuracy: 0.8700
# Epoch 129/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2975 - accuracy: 0.8670 - val_loss: 0.2937 - val_accuracy: 0.8690
# Epoch 130/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2974 - accuracy: 0.8670 - val_loss: 0.2939 - val_accuracy: 0.8690
# Epoch 131/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2974 - accuracy: 0.8670 - val_loss: 0.2939 - val_accuracy: 0.8690
# Epoch 132/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2974 - accuracy: 0.8670 - val_loss: 0.2936 - val_accuracy: 0.8690
# Epoch 133/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2974 - accuracy: 0.8670 - val_loss: 0.2934 - val_accuracy: 0.8700
# Epoch 134/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2974 - accuracy: 0.8670 - val_loss: 0.2937 - val_accuracy: 0.8690
# Epoch 135/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2972 - accuracy: 0.8670 - val_loss: 0.2936 - val_accuracy: 0.8690
# Epoch 136/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2972 - accuracy: 0.8670 - val_loss: 0.2938 - val_accuracy: 0.8690
# Epoch 137/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2972 - accuracy: 0.8670 - val_loss: 0.2935 - val_accuracy: 0.8690
# Epoch 138/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2972 - accuracy: 0.8670 - val_loss: 0.2935 - val_accuracy: 0.8690
# Epoch 139/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2971 - accuracy: 0.8670 - val_loss: 0.2933 - val_accuracy: 0.8690
# Epoch 140/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2972 - accuracy: 0.8670 - val_loss: 0.2930 - val_accuracy: 0.8700
# Epoch 141/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2971 - accuracy: 0.8670 - val_loss: 0.2929 - val_accuracy: 0.8710
# Epoch 142/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2972 - accuracy: 0.8670 - val_loss: 0.2935 - val_accuracy: 0.8700
# Epoch 143/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2970 - accuracy: 0.8670 - val_loss: 0.2933 - val_accuracy: 0.8700
# Epoch 144/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2971 - accuracy: 0.8680 - val_loss: 0.2936 - val_accuracy: 0.8690
# Epoch 145/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2969 - accuracy: 0.8680 - val_loss: 0.2933 - val_accuracy: 0.8690
# Epoch 146/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2970 - accuracy: 0.8680 - val_loss: 0.2933 - val_accuracy: 0.8700
# Epoch 147/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2968 - accuracy: 0.8670 - val_loss: 0.2931 - val_accuracy: 0.8690
# Epoch 148/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2967 - accuracy: 0.8670 - val_loss: 0.2929 - val_accuracy: 0.8690
# Epoch 149/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2967 - accuracy: 0.8670 - val_loss: 0.2927 - val_accuracy: 0.8700
# Epoch 150/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2967 - accuracy: 0.8670 - val_loss: 0.2925 - val_accuracy: 0.8700
# Epoch 151/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2967 - accuracy: 0.8670 - val_loss: 0.2927 - val_accuracy: 0.8700
# Epoch 152/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2966 - accuracy: 0.8670 - val_loss: 0.2929 - val_accuracy: 0.8690
# Epoch 153/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2966 - accuracy: 0.8670 - val_loss: 0.2930 - val_accuracy: 0.8690
# Epoch 154/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2965 - accuracy: 0.8670 - val_loss: 0.2930 - val_accuracy: 0.8690
# Epoch 155/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2965 - accuracy: 0.8670 - val_loss: 0.2926 - val_accuracy: 0.8700
# Epoch 156/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2964 - accuracy: 0.8670 - val_loss: 0.2925 - val_accuracy: 0.8700
# Epoch 157/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2964 - accuracy: 0.8670 - val_loss: 0.2926 - val_accuracy: 0.8690
# Epoch 158/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2964 - accuracy: 0.8670 - val_loss: 0.2924 - val_accuracy: 0.8700
# Epoch 159/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2963 - accuracy: 0.8670 - val_loss: 0.2927 - val_accuracy: 0.8690
# Epoch 160/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2962 - accuracy: 0.8680 - val_loss: 0.2928 - val_accuracy: 0.8690
# Epoch 161/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2962 - accuracy: 0.8680 - val_loss: 0.2927 - val_accuracy: 0.8690
# Epoch 162/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2961 - accuracy: 0.8670 - val_loss: 0.2923 - val_accuracy: 0.8690
# Epoch 163/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2963 - accuracy: 0.8670 - val_loss: 0.2925 - val_accuracy: 0.8690
# Epoch 164/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2960 - accuracy: 0.8680 - val_loss: 0.2922 - val_accuracy: 0.8690
# Epoch 165/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2960 - accuracy: 0.8670 - val_loss: 0.2920 - val_accuracy: 0.8700
# Epoch 166/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2960 - accuracy: 0.8670 - val_loss: 0.2919 - val_accuracy: 0.8700
# Epoch 167/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2959 - accuracy: 0.8670 - val_loss: 0.2920 - val_accuracy: 0.8700
# Epoch 168/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2958 - accuracy: 0.8670 - val_loss: 0.2920 - val_accuracy: 0.8690
# Epoch 169/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2958 - accuracy: 0.8670 - val_loss: 0.2921 - val_accuracy: 0.8690
# Epoch 170/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2958 - accuracy: 0.8680 - val_loss: 0.2924 - val_accuracy: 0.8690
# Epoch 171/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2959 - accuracy: 0.8680 - val_loss: 0.2920 - val_accuracy: 0.8700
# Epoch 172/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2957 - accuracy: 0.8680 - val_loss: 0.2922 - val_accuracy: 0.8690
# Epoch 173/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2957 - accuracy: 0.8680 - val_loss: 0.2921 - val_accuracy: 0.8690
# Epoch 174/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2955 - accuracy: 0.8680 - val_loss: 0.2919 - val_accuracy: 0.8690
# Epoch 175/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2957 - accuracy: 0.8670 - val_loss: 0.2915 - val_accuracy: 0.8700
# Epoch 176/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2955 - accuracy: 0.8670 - val_loss: 0.2916 - val_accuracy: 0.8690
# Epoch 177/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2954 - accuracy: 0.8670 - val_loss: 0.2916 - val_accuracy: 0.8690
# Epoch 178/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2954 - accuracy: 0.8670 - val_loss: 0.2918 - val_accuracy: 0.8690
# Epoch 179/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2953 - accuracy: 0.8680 - val_loss: 0.2916 - val_accuracy: 0.8690
# Epoch 180/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2954 - accuracy: 0.8680 - val_loss: 0.2918 - val_accuracy: 0.8710
# Epoch 181/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2951 - accuracy: 0.8680 - val_loss: 0.2916 - val_accuracy: 0.8690
# Epoch 182/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2952 - accuracy: 0.8670 - val_loss: 0.2911 - val_accuracy: 0.8700
# Epoch 183/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2951 - accuracy: 0.8670 - val_loss: 0.2910 - val_accuracy: 0.8700
# Epoch 184/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2950 - accuracy: 0.8670 - val_loss: 0.2910 - val_accuracy: 0.8700
# Epoch 185/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2949 - accuracy: 0.8670 - val_loss: 0.2913 - val_accuracy: 0.8690
# Epoch 186/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2948 - accuracy: 0.8680 - val_loss: 0.2916 - val_accuracy: 0.8720
# Epoch 187/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2950 - accuracy: 0.8680 - val_loss: 0.2913 - val_accuracy: 0.8690
# Epoch 188/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2948 - accuracy: 0.8680 - val_loss: 0.2913 - val_accuracy: 0.8700
# Epoch 189/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2948 - accuracy: 0.8680 - val_loss: 0.2915 - val_accuracy: 0.8720
# Epoch 190/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2946 - accuracy: 0.8680 - val_loss: 0.2912 - val_accuracy: 0.8720
# Epoch 191/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2946 - accuracy: 0.8680 - val_loss: 0.2908 - val_accuracy: 0.8690
# Epoch 192/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2945 - accuracy: 0.8680 - val_loss: 0.2906 - val_accuracy: 0.8700
# Epoch 193/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2944 - accuracy: 0.8680 - val_loss: 0.2907 - val_accuracy: 0.8690
# Epoch 194/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2944 - accuracy: 0.8680 - val_loss: 0.2908 - val_accuracy: 0.8720
# Epoch 195/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2943 - accuracy: 0.8680 - val_loss: 0.2908 - val_accuracy: 0.8730
# Epoch 196/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2942 - accuracy: 0.8680 - val_loss: 0.2906 - val_accuracy: 0.8710
# Epoch 197/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2941 - accuracy: 0.8680 - val_loss: 0.2903 - val_accuracy: 0.8690
# Epoch 198/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2941 - accuracy: 0.8680 - val_loss: 0.2904 - val_accuracy: 0.8690
# Epoch 199/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2941 - accuracy: 0.8670 - val_loss: 0.2899 - val_accuracy: 0.8700
# Epoch 200/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2940 - accuracy: 0.8670 - val_loss: 0.2897 - val_accuracy: 0.8700
# Epoch 201/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2939 - accuracy: 0.8670 - val_loss: 0.2898 - val_accuracy: 0.8700
# Epoch 202/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2938 - accuracy: 0.8680 - val_loss: 0.2904 - val_accuracy: 0.8730
# Epoch 203/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2936 - accuracy: 0.8690 - val_loss: 0.2904 - val_accuracy: 0.8740
# Epoch 204/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2937 - accuracy: 0.8680 - val_loss: 0.2901 - val_accuracy: 0.8720
# Epoch 205/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2936 - accuracy: 0.8680 - val_loss: 0.2897 - val_accuracy: 0.8690
# Epoch 206/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2934 - accuracy: 0.8680 - val_loss: 0.2898 - val_accuracy: 0.8720
# Epoch 207/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2934 - accuracy: 0.8680 - val_loss: 0.2896 - val_accuracy: 0.8720
# Epoch 208/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2932 - accuracy: 0.8680 - val_loss: 0.2899 - val_accuracy: 0.8740
# Epoch 209/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2932 - accuracy: 0.8680 - val_loss: 0.2900 - val_accuracy: 0.8740
# Epoch 210/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2931 - accuracy: 0.8680 - val_loss: 0.2894 - val_accuracy: 0.8740
# Epoch 211/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2930 - accuracy: 0.8680 - val_loss: 0.2891 - val_accuracy: 0.8720
# Epoch 212/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2930 - accuracy: 0.8670 - val_loss: 0.2887 - val_accuracy: 0.8700
# Epoch 213/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2927 - accuracy: 0.8680 - val_loss: 0.2890 - val_accuracy: 0.8720
# Epoch 214/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2926 - accuracy: 0.8680 - val_loss: 0.2891 - val_accuracy: 0.8740
# Epoch 215/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2925 - accuracy: 0.8690 - val_loss: 0.2891 - val_accuracy: 0.8740
# Epoch 216/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2924 - accuracy: 0.8690 - val_loss: 0.2891 - val_accuracy: 0.8740
# Epoch 217/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2923 - accuracy: 0.8690 - val_loss: 0.2889 - val_accuracy: 0.8740
# Epoch 218/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2922 - accuracy: 0.8680 - val_loss: 0.2884 - val_accuracy: 0.8730
# Epoch 219/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2922 - accuracy: 0.8680 - val_loss: 0.2880 - val_accuracy: 0.8690
# Epoch 220/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2919 - accuracy: 0.8680 - val_loss: 0.2881 - val_accuracy: 0.8730
# Epoch 221/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2920 - accuracy: 0.8700 - val_loss: 0.2886 - val_accuracy: 0.8750
# Epoch 222/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2918 - accuracy: 0.8690 - val_loss: 0.2886 - val_accuracy: 0.8750
# Epoch 223/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2916 - accuracy: 0.8700 - val_loss: 0.2882 - val_accuracy: 0.8740
# Epoch 224/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2916 - accuracy: 0.8700 - val_loss: 0.2876 - val_accuracy: 0.8740
# Epoch 225/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2913 - accuracy: 0.8680 - val_loss: 0.2873 - val_accuracy: 0.8740
# Epoch 226/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2913 - accuracy: 0.8680 - val_loss: 0.2870 - val_accuracy: 0.8720
# Epoch 227/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2911 - accuracy: 0.8680 - val_loss: 0.2872 - val_accuracy: 0.8750
# Epoch 228/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2908 - accuracy: 0.8690 - val_loss: 0.2873 - val_accuracy: 0.8740
# Epoch 229/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2908 - accuracy: 0.8690 - val_loss: 0.2873 - val_accuracy: 0.8750
# Epoch 230/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2908 - accuracy: 0.8710 - val_loss: 0.2874 - val_accuracy: 0.8760
# Epoch 231/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2904 - accuracy: 0.8700 - val_loss: 0.2869 - val_accuracy: 0.8750
# Epoch 232/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2902 - accuracy: 0.8710 - val_loss: 0.2864 - val_accuracy: 0.8740
# Epoch 233/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2902 - accuracy: 0.8710 - val_loss: 0.2864 - val_accuracy: 0.8740
# Epoch 234/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2899 - accuracy: 0.8710 - val_loss: 0.2862 - val_accuracy: 0.8740
# Epoch 235/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2898 - accuracy: 0.8710 - val_loss: 0.2860 - val_accuracy: 0.8750
# Epoch 236/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2897 - accuracy: 0.8710 - val_loss: 0.2857 - val_accuracy: 0.8750
# Epoch 237/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2895 - accuracy: 0.8690 - val_loss: 0.2854 - val_accuracy: 0.8750
# Epoch 238/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2894 - accuracy: 0.8690 - val_loss: 0.2851 - val_accuracy: 0.8750
# Epoch 239/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2892 - accuracy: 0.8690 - val_loss: 0.2856 - val_accuracy: 0.8770
# Epoch 240/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2889 - accuracy: 0.8700 - val_loss: 0.2855 - val_accuracy: 0.8770
# Epoch 241/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2889 - accuracy: 0.8700 - val_loss: 0.2847 - val_accuracy: 0.8770
# Epoch 242/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2888 - accuracy: 0.8690 - val_loss: 0.2851 - val_accuracy: 0.8770
# Epoch 243/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2883 - accuracy: 0.8710 - val_loss: 0.2844 - val_accuracy: 0.8780
# Epoch 244/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2881 - accuracy: 0.8710 - val_loss: 0.2840 - val_accuracy: 0.8770
# Epoch 245/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2878 - accuracy: 0.8700 - val_loss: 0.2840 - val_accuracy: 0.8780
# Epoch 246/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2878 - accuracy: 0.8710 - val_loss: 0.2841 - val_accuracy: 0.8770
# Epoch 247/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2875 - accuracy: 0.8710 - val_loss: 0.2832 - val_accuracy: 0.8770
# Epoch 248/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2871 - accuracy: 0.8710 - val_loss: 0.2830 - val_accuracy: 0.8790
# Epoch 249/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2869 - accuracy: 0.8710 - val_loss: 0.2827 - val_accuracy: 0.8780
# Epoch 250/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2866 - accuracy: 0.8710 - val_loss: 0.2826 - val_accuracy: 0.8790
# Epoch 251/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2863 - accuracy: 0.8710 - val_loss: 0.2826 - val_accuracy: 0.8780
# Epoch 252/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2861 - accuracy: 0.8710 - val_loss: 0.2823 - val_accuracy: 0.8780
# Epoch 253/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2858 - accuracy: 0.8720 - val_loss: 0.2819 - val_accuracy: 0.8780
# Epoch 254/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2857 - accuracy: 0.8720 - val_loss: 0.2813 - val_accuracy: 0.8790
# Epoch 255/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2854 - accuracy: 0.8710 - val_loss: 0.2817 - val_accuracy: 0.8790
# Epoch 256/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2850 - accuracy: 0.8710 - val_loss: 0.2814 - val_accuracy: 0.8790
# Epoch 257/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2847 - accuracy: 0.8710 - val_loss: 0.2806 - val_accuracy: 0.8800
# Epoch 258/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2843 - accuracy: 0.8720 - val_loss: 0.2798 - val_accuracy: 0.8800
# Epoch 259/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2840 - accuracy: 0.8710 - val_loss: 0.2797 - val_accuracy: 0.8800
# Epoch 260/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2837 - accuracy: 0.8710 - val_loss: 0.2796 - val_accuracy: 0.8810
# Epoch 261/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2835 - accuracy: 0.8720 - val_loss: 0.2793 - val_accuracy: 0.8810
# Epoch 262/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2830 - accuracy: 0.8710 - val_loss: 0.2785 - val_accuracy: 0.8810
# Epoch 263/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2825 - accuracy: 0.8710 - val_loss: 0.2782 - val_accuracy: 0.8810
# Epoch 264/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2822 - accuracy: 0.8710 - val_loss: 0.2777 - val_accuracy: 0.8810
# Epoch 265/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2818 - accuracy: 0.8710 - val_loss: 0.2777 - val_accuracy: 0.8810
# Epoch 266/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2814 - accuracy: 0.8720 - val_loss: 0.2771 - val_accuracy: 0.8810
# Epoch 267/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2810 - accuracy: 0.8720 - val_loss: 0.2770 - val_accuracy: 0.8820
# Epoch 268/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2806 - accuracy: 0.8720 - val_loss: 0.2761 - val_accuracy: 0.8820
# Epoch 269/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2800 - accuracy: 0.8720 - val_loss: 0.2756 - val_accuracy: 0.8820
# Epoch 270/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2796 - accuracy: 0.8720 - val_loss: 0.2752 - val_accuracy: 0.8830
# Epoch 271/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2792 - accuracy: 0.8720 - val_loss: 0.2748 - val_accuracy: 0.8830
# Epoch 272/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2787 - accuracy: 0.8720 - val_loss: 0.2736 - val_accuracy: 0.8830
# Epoch 273/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2782 - accuracy: 0.8730 - val_loss: 0.2731 - val_accuracy: 0.8830
# Epoch 274/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2778 - accuracy: 0.8720 - val_loss: 0.2730 - val_accuracy: 0.8840
# Epoch 275/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2771 - accuracy: 0.8720 - val_loss: 0.2727 - val_accuracy: 0.8850
# Epoch 276/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2765 - accuracy: 0.8730 - val_loss: 0.2719 - val_accuracy: 0.8850
# Epoch 277/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2759 - accuracy: 0.8720 - val_loss: 0.2708 - val_accuracy: 0.8840
# Epoch 278/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2754 - accuracy: 0.8720 - val_loss: 0.2701 - val_accuracy: 0.8840
# Epoch 279/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2752 - accuracy: 0.8730 - val_loss: 0.2701 - val_accuracy: 0.8850
# Epoch 280/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2741 - accuracy: 0.8720 - val_loss: 0.2688 - val_accuracy: 0.8850
# Epoch 281/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2734 - accuracy: 0.8740 - val_loss: 0.2682 - val_accuracy: 0.8860
# Epoch 282/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2728 - accuracy: 0.8750 - val_loss: 0.2676 - val_accuracy: 0.8860
# Epoch 283/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2721 - accuracy: 0.8750 - val_loss: 0.2667 - val_accuracy: 0.8870
# Epoch 284/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2714 - accuracy: 0.8750 - val_loss: 0.2659 - val_accuracy: 0.8880
# Epoch 285/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2707 - accuracy: 0.8750 - val_loss: 0.2651 - val_accuracy: 0.8870
# Epoch 286/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2699 - accuracy: 0.8760 - val_loss: 0.2647 - val_accuracy: 0.8860
# Epoch 287/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2692 - accuracy: 0.8770 - val_loss: 0.2640 - val_accuracy: 0.8850
# Epoch 288/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2683 - accuracy: 0.8760 - val_loss: 0.2628 - val_accuracy: 0.8870
# Epoch 289/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2675 - accuracy: 0.8770 - val_loss: 0.2619 - val_accuracy: 0.8890
# Epoch 290/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2667 - accuracy: 0.8770 - val_loss: 0.2607 - val_accuracy: 0.8890
# Epoch 291/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2659 - accuracy: 0.8770 - val_loss: 0.2601 - val_accuracy: 0.8890
# Epoch 292/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2649 - accuracy: 0.8780 - val_loss: 0.2590 - val_accuracy: 0.8890
# Epoch 293/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2641 - accuracy: 0.8780 - val_loss: 0.2578 - val_accuracy: 0.8900
# Epoch 294/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2630 - accuracy: 0.8790 - val_loss: 0.2568 - val_accuracy: 0.8900
# Epoch 295/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2621 - accuracy: 0.8790 - val_loss: 0.2555 - val_accuracy: 0.8910
# Epoch 296/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2611 - accuracy: 0.8800 - val_loss: 0.2545 - val_accuracy: 0.8910
# Epoch 297/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2602 - accuracy: 0.8790 - val_loss: 0.2539 - val_accuracy: 0.8910
# Epoch 298/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2590 - accuracy: 0.8820 - val_loss: 0.2525 - val_accuracy: 0.8910
# Epoch 299/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2580 - accuracy: 0.8820 - val_loss: 0.2512 - val_accuracy: 0.8910
# Epoch 300/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2571 - accuracy: 0.8810 - val_loss: 0.2497 - val_accuracy: 0.8930
# Epoch 301/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2559 - accuracy: 0.8830 - val_loss: 0.2485 - val_accuracy: 0.8930
# Epoch 302/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2546 - accuracy: 0.8840 - val_loss: 0.2480 - val_accuracy: 0.8920
# Epoch 303/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2535 - accuracy: 0.8850 - val_loss: 0.2469 - val_accuracy: 0.8930
# Epoch 304/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2524 - accuracy: 0.8850 - val_loss: 0.2453 - val_accuracy: 0.8920
# Epoch 305/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2511 - accuracy: 0.8860 - val_loss: 0.2436 - val_accuracy: 0.8950
# Epoch 306/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2499 - accuracy: 0.8870 - val_loss: 0.2421 - val_accuracy: 0.8960
# Epoch 307/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2485 - accuracy: 0.8860 - val_loss: 0.2406 - val_accuracy: 0.8960
# Epoch 308/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2473 - accuracy: 0.8880 - val_loss: 0.2395 - val_accuracy: 0.8980
# Epoch 309/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2463 - accuracy: 0.8910 - val_loss: 0.2388 - val_accuracy: 0.8980
# Epoch 310/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2446 - accuracy: 0.8910 - val_loss: 0.2366 - val_accuracy: 0.9000
# Epoch 311/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2431 - accuracy: 0.8910 - val_loss: 0.2348 - val_accuracy: 0.9010
# Epoch 312/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2418 - accuracy: 0.8920 - val_loss: 0.2333 - val_accuracy: 0.9010
# Epoch 313/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2405 - accuracy: 0.8940 - val_loss: 0.2317 - val_accuracy: 0.9010
# Epoch 314/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2389 - accuracy: 0.8940 - val_loss: 0.2303 - val_accuracy: 0.9020
# Epoch 315/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2374 - accuracy: 0.8970 - val_loss: 0.2289 - val_accuracy: 0.9030
# Epoch 316/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2360 - accuracy: 0.8970 - val_loss: 0.2276 - val_accuracy: 0.9050
# Epoch 317/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2345 - accuracy: 0.8980 - val_loss: 0.2257 - val_accuracy: 0.9060
# Epoch 318/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2327 - accuracy: 0.8980 - val_loss: 0.2237 - val_accuracy: 0.9060
# Epoch 319/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2312 - accuracy: 0.8970 - val_loss: 0.2217 - val_accuracy: 0.9060
# Epoch 320/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2297 - accuracy: 0.9010 - val_loss: 0.2201 - val_accuracy: 0.9070
# Epoch 321/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2280 - accuracy: 0.9020 - val_loss: 0.2186 - val_accuracy: 0.9110
# Epoch 322/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2264 - accuracy: 0.9010 - val_loss: 0.2171 - val_accuracy: 0.9130
# Epoch 323/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2250 - accuracy: 0.9030 - val_loss: 0.2155 - val_accuracy: 0.9140
# Epoch 324/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2230 - accuracy: 0.9050 - val_loss: 0.2131 - val_accuracy: 0.9130
# Epoch 325/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2213 - accuracy: 0.9070 - val_loss: 0.2110 - val_accuracy: 0.9140
# Epoch 326/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2198 - accuracy: 0.9070 - val_loss: 0.2091 - val_accuracy: 0.9150
# Epoch 327/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2180 - accuracy: 0.9090 - val_loss: 0.2079 - val_accuracy: 0.9170
# Epoch 328/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2163 - accuracy: 0.9080 - val_loss: 0.2062 - val_accuracy: 0.9180
# Epoch 329/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2143 - accuracy: 0.9100 - val_loss: 0.2041 - val_accuracy: 0.9190
# Epoch 330/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2127 - accuracy: 0.9120 - val_loss: 0.2017 - val_accuracy: 0.9190
# Epoch 331/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2109 - accuracy: 0.9130 - val_loss: 0.1998 - val_accuracy: 0.9190
# Epoch 332/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2089 - accuracy: 0.9140 - val_loss: 0.1981 - val_accuracy: 0.9200
# Epoch 333/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2071 - accuracy: 0.9130 - val_loss: 0.1965 - val_accuracy: 0.9210
# Epoch 334/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2053 - accuracy: 0.9160 - val_loss: 0.1943 - val_accuracy: 0.9200
# Epoch 335/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2035 - accuracy: 0.9170 - val_loss: 0.1922 - val_accuracy: 0.9190
# Epoch 336/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2017 - accuracy: 0.9170 - val_loss: 0.1902 - val_accuracy: 0.9230
# Epoch 337/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1996 - accuracy: 0.9190 - val_loss: 0.1884 - val_accuracy: 0.9240
# Epoch 338/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1977 - accuracy: 0.9200 - val_loss: 0.1865 - val_accuracy: 0.9240
# Epoch 339/1000
# ...
# Epoch 466/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0865 - accuracy: 0.9710 - val_loss: 0.0841 - val_accuracy: 0.9730
# Epoch 467/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0858 - accuracy: 0.9720 - val_loss: 0.0842 - val_accuracy: 0.9750
# Epoch 468/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0858 - accuracy: 0.9720 - val_loss: 0.0840 - val_accuracy: 0.9740
# Epoch 469/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0851 - accuracy: 0.9710 - val_loss: 0.0839 - val_accuracy: 0.9740
# Epoch 470/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0850 - accuracy: 0.9710 - val_loss: 0.0837 - val_accuracy: 0.9740
# Epoch 471/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0847 - accuracy: 0.9710 - val_loss: 0.0836 - val_accuracy: 0.9740
# Epoch 472/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0848 - accuracy: 0.9710 - val_loss: 0.0836 - val_accuracy: 0.9740
# Epoch 473/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0847 - accuracy: 0.9710 - val_loss: 0.0834 - val_accuracy: 0.9730
# Epoch 474/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0845 - accuracy: 0.9710 - val_loss: 0.0833 - val_accuracy: 0.9740
# Epoch 475/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0841 - accuracy: 0.9710 - val_loss: 0.0832 - val_accuracy: 0.9730
# Epoch 476/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0841 - accuracy: 0.9730 - val_loss: 0.0833 - val_accuracy: 0.9750
# Epoch 477/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0839 - accuracy: 0.9710 - val_loss: 0.0831 - val_accuracy: 0.9740
# Epoch 478/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0839 - accuracy: 0.9710 - val_loss: 0.0830 - val_accuracy: 0.9730
# Epoch 479/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0835 - accuracy: 0.9710 - val_loss: 0.0829 - val_accuracy: 0.9740
# Epoch 480/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0834 - accuracy: 0.9720 - val_loss: 0.0830 - val_accuracy: 0.9730
# Epoch 481/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0833 - accuracy: 0.9720 - val_loss: 0.0827 - val_accuracy: 0.9740
# Epoch 482/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0831 - accuracy: 0.9710 - val_loss: 0.0828 - val_accuracy: 0.9750
# Epoch 483/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0834 - accuracy: 0.9710 - val_loss: 0.0828 - val_accuracy: 0.9730
# Epoch 484/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0834 - accuracy: 0.9720 - val_loss: 0.0825 - val_accuracy: 0.9730
# Epoch 485/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0826 - accuracy: 0.9710 - val_loss: 0.0825 - val_accuracy: 0.9750
# Epoch 486/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0826 - accuracy: 0.9730 - val_loss: 0.0825 - val_accuracy: 0.9750
# Epoch 487/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0831 - accuracy: 0.9720 - val_loss: 0.0828 - val_accuracy: 0.9720
# Epoch 488/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0823 - accuracy: 0.9720 - val_loss: 0.0823 - val_accuracy: 0.9740
# Epoch 489/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0820 - accuracy: 0.9710 - val_loss: 0.0823 - val_accuracy: 0.9750
# Epoch 490/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0822 - accuracy: 0.9730 - val_loss: 0.0822 - val_accuracy: 0.9740
# Epoch 491/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0835 - accuracy: 0.9700 - val_loss: 0.0825 - val_accuracy: 0.9720
# Epoch 492/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0818 - accuracy: 0.9730 - val_loss: 0.0820 - val_accuracy: 0.9750
# Epoch 493/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0816 - accuracy: 0.9730 - val_loss: 0.0820 - val_accuracy: 0.9750
# Epoch 494/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0814 - accuracy: 0.9730 - val_loss: 0.0819 - val_accuracy: 0.9750
# Epoch 495/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0813 - accuracy: 0.9730 - val_loss: 0.0818 - val_accuracy: 0.9730
# Epoch 496/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0812 - accuracy: 0.9730 - val_loss: 0.0818 - val_accuracy: 0.9750
# Epoch 497/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0808 - accuracy: 0.9730 - val_loss: 0.0817 - val_accuracy: 0.9730
# Epoch 498/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0810 - accuracy: 0.9730 - val_loss: 0.0817 - val_accuracy: 0.9730
# Epoch 499/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0809 - accuracy: 0.9720 - val_loss: 0.0816 - val_accuracy: 0.9730
# Epoch 500/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0808 - accuracy: 0.9710 - val_loss: 0.0818 - val_accuracy: 0.9750
# Epoch 501/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0807 - accuracy: 0.9730 - val_loss: 0.0818 - val_accuracy: 0.9730
# Epoch 502/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0806 - accuracy: 0.9720 - val_loss: 0.0817 - val_accuracy: 0.9720
# Epoch 503/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0806 - accuracy: 0.9720 - val_loss: 0.0815 - val_accuracy: 0.9730
# Epoch 504/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0802 - accuracy: 0.9730 - val_loss: 0.0814 - val_accuracy: 0.9750
# Epoch 505/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0800 - accuracy: 0.9740 - val_loss: 0.0814 - val_accuracy: 0.9740
# Epoch 506/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0800 - accuracy: 0.9740 - val_loss: 0.0814 - val_accuracy: 0.9740
# Epoch 507/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0800 - accuracy: 0.9740 - val_loss: 0.0813 - val_accuracy: 0.9740
# Epoch 508/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0801 - accuracy: 0.9740 - val_loss: 0.0812 - val_accuracy: 0.9740
# Epoch 509/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0796 - accuracy: 0.9730 - val_loss: 0.0814 - val_accuracy: 0.9730
# Epoch 510/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0797 - accuracy: 0.9730 - val_loss: 0.0816 - val_accuracy: 0.9720
# Epoch 511/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0797 - accuracy: 0.9730 - val_loss: 0.0811 - val_accuracy: 0.9730
# Epoch 512/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0796 - accuracy: 0.9740 - val_loss: 0.0811 - val_accuracy: 0.9750
# Epoch 513/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0794 - accuracy: 0.9740 - val_loss: 0.0811 - val_accuracy: 0.9730
# Epoch 514/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0793 - accuracy: 0.9730 - val_loss: 0.0810 - val_accuracy: 0.9730
# Epoch 515/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0791 - accuracy: 0.9730 - val_loss: 0.0812 - val_accuracy: 0.9720
# Epoch 516/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0791 - accuracy: 0.9730 - val_loss: 0.0809 - val_accuracy: 0.9730
# Epoch 517/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0791 - accuracy: 0.9730 - val_loss: 0.0809 - val_accuracy: 0.9740
# Epoch 518/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0788 - accuracy: 0.9740 - val_loss: 0.0810 - val_accuracy: 0.9730
# Epoch 519/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0787 - accuracy: 0.9740 - val_loss: 0.0811 - val_accuracy: 0.9730
# Epoch 520/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0793 - accuracy: 0.9720 - val_loss: 0.0813 - val_accuracy: 0.9730
# Epoch 521/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0788 - accuracy: 0.9720 - val_loss: 0.0809 - val_accuracy: 0.9730
# Epoch 522/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0790 - accuracy: 0.9730 - val_loss: 0.0808 - val_accuracy: 0.9750
# Epoch 523/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0787 - accuracy: 0.9730 - val_loss: 0.0808 - val_accuracy: 0.9730
# Epoch 524/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0786 - accuracy: 0.9720 - val_loss: 0.0812 - val_accuracy: 0.9730
# Epoch 525/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0783 - accuracy: 0.9720 - val_loss: 0.0812 - val_accuracy: 0.9730
# Epoch 526/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0782 - accuracy: 0.9730 - val_loss: 0.0811 - val_accuracy: 0.9730
# Epoch 527/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0783 - accuracy: 0.9730 - val_loss: 0.0808 - val_accuracy: 0.9740
# Epoch 528/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0781 - accuracy: 0.9740 - val_loss: 0.0807 - val_accuracy: 0.9740
# Epoch 529/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0780 - accuracy: 0.9730 - val_loss: 0.0809 - val_accuracy: 0.9720
# Epoch 530/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0781 - accuracy: 0.9710 - val_loss: 0.0809 - val_accuracy: 0.9730
# Epoch 531/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0777 - accuracy: 0.9750 - val_loss: 0.0808 - val_accuracy: 0.9730
# Epoch 532/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0785 - accuracy: 0.9740 - val_loss: 0.0810 - val_accuracy: 0.9720
# Epoch 533/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0777 - accuracy: 0.9740 - val_loss: 0.0807 - val_accuracy: 0.9730
# Epoch 534/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0775 - accuracy: 0.9710 - val_loss: 0.0809 - val_accuracy: 0.9720
# Epoch 535/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0777 - accuracy: 0.9710 - val_loss: 0.0806 - val_accuracy: 0.9730
# Epoch 536/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0774 - accuracy: 0.9740 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 537/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0778 - accuracy: 0.9750 - val_loss: 0.0808 - val_accuracy: 0.9730
# Epoch 538/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0774 - accuracy: 0.9750 - val_loss: 0.0807 - val_accuracy: 0.9730
# Epoch 539/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0775 - accuracy: 0.9730 - val_loss: 0.0806 - val_accuracy: 0.9730
# Epoch 540/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0774 - accuracy: 0.9730 - val_loss: 0.0806 - val_accuracy: 0.9730
# Epoch 541/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0772 - accuracy: 0.9740 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 542/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 0.9730 - val_loss: 0.0809 - val_accuracy: 0.9730
# Epoch 543/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0771 - accuracy: 0.9710 - val_loss: 0.0808 - val_accuracy: 0.9730
# Epoch 544/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0770 - accuracy: 0.9730 - val_loss: 0.0808 - val_accuracy: 0.9730
# Epoch 545/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0770 - accuracy: 0.9750 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 546/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0771 - accuracy: 0.9720 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 547/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 0.9730 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 548/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0773 - accuracy: 0.9720 - val_loss: 0.0810 - val_accuracy: 0.9730
# Epoch 549/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0770 - accuracy: 0.9720 - val_loss: 0.0808 - val_accuracy: 0.9730
# Epoch 550/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0768 - accuracy: 0.9730 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 551/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0766 - accuracy: 0.9730 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 552/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0768 - accuracy: 0.9710 - val_loss: 0.0807 - val_accuracy: 0.9730
# Epoch 553/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0764 - accuracy: 0.9710 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 554/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0770 - accuracy: 0.9740 - val_loss: 0.0808 - val_accuracy: 0.9720
# Epoch 555/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0765 - accuracy: 0.9740 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 556/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0762 - accuracy: 0.9740 - val_loss: 0.0804 - val_accuracy: 0.9730
# Epoch 557/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0763 - accuracy: 0.9740 - val_loss: 0.0804 - val_accuracy: 0.9730
# Epoch 558/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0766 - accuracy: 0.9730 - val_loss: 0.0806 - val_accuracy: 0.9730
# Epoch 559/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0762 - accuracy: 0.9730 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 560/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0761 - accuracy: 0.9730 - val_loss: 0.0807 - val_accuracy: 0.9730
# Epoch 561/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0762 - accuracy: 0.9720 - val_loss: 0.0807 - val_accuracy: 0.9730
# Epoch 562/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0765 - accuracy: 0.9700 - val_loss: 0.0807 - val_accuracy: 0.9730
# Epoch 563/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0767 - accuracy: 0.9730 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 564/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0761 - accuracy: 0.9750 - val_loss: 0.0805 - val_accuracy: 0.9730
# Epoch 565/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0758 - accuracy: 0.9730 - val_loss: 0.0806 - val_accuracy: 0.9730
# Epoch 566/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0764 - accuracy: 0.9700 - val_loss: 0.0810 - val_accuracy: 0.9720
# Epoch 567/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0759 - accuracy: 0.9710 - val_loss: 0.0804 - val_accuracy: 0.9730
# Epoch 568/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0755 - accuracy: 0.9730 - val_loss: 0.0806 - val_accuracy: 0.9730
# Epoch 569/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0762 - accuracy: 0.9750 - val_loss: 0.0809 - val_accuracy: 0.9710
# Epoch 570/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9740 - val_loss: 0.0807 - val_accuracy: 0.9730
# Epoch 571/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0758 - accuracy: 0.9720 - val_loss: 0.0806 - val_accuracy: 0.9730
# Epoch 572/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0760 - accuracy: 0.9710 - val_loss: 0.0807 - val_accuracy: 0.9730
# Epoch 573/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9720 - val_loss: 0.0809 - val_accuracy: 0.9720
# Epoch 574/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0762 - accuracy: 0.9750 - val_loss: 0.0810 - val_accuracy: 0.9710
# Epoch 575/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9740 - val_loss: 0.0806 - val_accuracy: 0.9730
# Epoch 576/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0755 - accuracy: 0.9730 - val_loss: 0.0804 - val_accuracy: 0.9730
# Epoch 577/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9710 - val_loss: 0.0806 - val_accuracy: 0.9730

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,5))
ax[0].plot(history.history["val_loss"], label="validation loss")
ax[0].plot(history.history["loss"], label="training loss")
ax[0].set_title("plot of loss over iterations")
ax[0].legend()
ax[1].plot(history.history["val_accuracy"], label="validation accuracy")
ax[1].plot(history.history["accuracy"], label="training accuracy")
ax[1].set_title("plot of loss over iterations")
ax[1].legend()
plt.show()

# %%
weights = base_model.get_weights()
base_model.save_weights('initial_model_weights.h5')

# %%
grid = pm.floatX(np.mgrid[-3:3:100j,-3:3:100j])
grid_2d = grid.reshape(2, -1).T
dummy_out = np.ones(grid.shape[1], dtype=np.int8)

# %%
pred2 = base_model.predict(grid_2d)[:,0].flatten()
pred = base_model.predict(X_test)[:,0].flatten() > 0.5

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], pred2.reshape(100, 100), cmap=cmap)
ax.scatter(X_test[pred==0, 0], X_test[pred==0, 1], color='b')
ax.scatter(X_test[pred==1, 0], X_test[pred==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y')
plt.title("prediction probabilities - (Test Set)")
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
# Out:
# Text(0, 0.5, 'posterior predictive mean probability of class label = 0')

# %% [markdown]
# <a id='deep-ensemble'></a>
# ## 3. Deep Ensemble with Random Initialization

# %%
ensembles = 30
ens_test_probs = []
ens_ood_probs = []
ens_weights = []
grid_preds = []

for i in range(ensembles):
    
    # Fit neural network model
    model = get_model(mc=False)
    nn = model.fit(X_train, Y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=0,
                        callbacks=[es],
                    validation_data=(X_test, Y_test))
    
    #Get Dense model weights
    weights = model.get_weights()
    flat_weight_array = np.array([])
    for weight in weights:
        flat_weight_array = np.concatenate((flat_weight_array, weight.flatten()))
    ens_weights.append(flat_weight_array)
    
    # Accuracy of model
    score = model.evaluate(X_test, Y_test, verbose=0)
    #print('Test loss:', np.round(score[0],2))
    test_prob = model.predict(X_test)
    
    ens_test_probs.append(test_prob)
    print("Iteration: " + str(i+1) +' Test accuracy:'+ str(np.round(score[1],4)))
        
    #Predictions & uncertainty for test points
    ood_prob = model.predict(np.array(test_points))
    ens_ood_probs.append(ood_prob)

    pred2 = model.predict(grid_2d)[:,0].flatten()
    grid_preds.append(pred2)
# Out:
# Iteration: 1 Test accuracy:0.972
# Iteration: 2 Test accuracy:0.972
# Iteration: 3 Test accuracy:0.971
# Iteration: 4 Test accuracy:0.971
# Iteration: 5 Test accuracy:0.971
# Iteration: 6 Test accuracy:0.972
# Iteration: 7 Test accuracy:0.973
# Iteration: 8 Test accuracy:0.973
# Iteration: 9 Test accuracy:0.973
# Iteration: 10 Test accuracy:0.971
# Iteration: 11 Test accuracy:0.973
# Iteration: 12 Test accuracy:0.971
# Iteration: 13 Test accuracy:0.972
# Iteration: 14 Test accuracy:0.973
# Iteration: 15 Test accuracy:0.97
# Iteration: 16 Test accuracy:0.97
# Iteration: 17 Test accuracy:0.972
# Iteration: 18 Test accuracy:0.972
# Iteration: 19 Test accuracy:0.972
# Iteration: 20 Test accuracy:0.97
# Iteration: 21 Test accuracy:0.971
# Iteration: 22 Test accuracy:0.971
# Iteration: 23 Test accuracy:0.973
# Iteration: 24 Test accuracy:0.973
# Iteration: 25 Test accuracy:0.973
# Iteration: 26 Test accuracy:0.971
# Iteration: 27 Test accuracy:0.971
# Iteration: 28 Test accuracy:0.971
# Iteration: 29 Test accuracy:0.972
# Iteration: 30 Test accuracy:0.972

# %%
ens_mean = np.mean(np.array(ens_test_probs),axis=0)
pred_test_labels = (ens_mean > 0.5).astype(np.int) 
score = accuracy_score(Y_test, pred_test_labels)
print("Ensemble prediction accuracy score for test data: ", score)
# Out:
# Ensemble prediction accuracy score for test data:  0.972

# %%
ens_variance = np.std(np.array(ens_ood_probs),axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], ens_variance[i][0]))
# Out:
# uncertainty for test point: (0.5, -0.4) : 1.7756930503765034e-07
# uncertainty for test point: (0.5, 0.8) : 1.5285568224499002e-06
# uncertainty for test point: (0.5, 0.25) : 0.0023369728587567806
# uncertainty for test point: (-0.8, 0.5) : 2.5279382498410996e-06
# uncertainty for test point: (1.7, -0.3) : 7.32027132244184e-08
# uncertainty for test point: (-1.5, -3) : 1.3759626771303601e-09
# uncertainty for test point: (-1.5, 3) : 5.12038411670801e-09
# uncertainty for test point: (3, -3) : 2.3674588955913123e-09
# uncertainty for test point: (3, 3) : 0.012536171823740005

# %%
df = pd.DataFrame(np.array(ens_weights))

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of deep ensemble weights ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cos_similarity_plot_ensemble.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.mean(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for the deep ensemble model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_ensemble.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.std(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for the deep ensemble model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_ensemble.png".format(TOY_DATA_TYPE))

# %%
tsne = TSNE(n_components=2)
ens_test_probs_pca = tsne.fit_transform(np.array(ens_test_probs).reshape(30, 1000))


plt.scatter(ens_test_probs_pca[:,0], ens_test_probs_pca[:,1])
plt.title("TSNE plot of predictions for the deep ensemble model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_ensemble.png".format(TOY_DATA_TYPE))

# %% [markdown]
# <a id='dropout'></a>
# ## 4. Dropout Subspace Sampling

# %%
bayes_iters = 30
dropout_post_predictions = []
dropout_ood_probs = []
drop_weights = []
grid_preds = []

for i in range(bayes_iters):
    #Generate random p value for Dropout ratio
    p_rand = np.random.random()
    
    drop_model = get_model(mc=True, p=p_rand)
    
    #Initialize model with pre-trained weights
    drop_model.load_weights('initial_model_weights.h5')
    h_mc = drop_model.fit(X_train, Y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=0,
                        callbacks=[es],
                        validation_data=(X_test, Y_test))
    
    #Get Dense model weights
    weights = drop_model.get_weights()
    flat_weight_array = np.array([])
    for weight in weights:
        flat_weight_array = np.concatenate((flat_weight_array, weight.flatten()))
    drop_weights.append(flat_weight_array)
    
    # Accuracy of model
    score = drop_model.evaluate(X_test, Y_test, verbose=0)
    #print('Test loss:', np.round(score[0],2))
    print("Iteration: " + str(i+1) + " Random p: " + str(np.round(p_rand,2)) + ' Test accuracy: ', str(np.round(score[1],4)))
    
    #Posterior predictions
    y_pred = drop_model.predict(X_test)
    dropout_post_predictions.append(y_pred)
    
    #Predictions & uncertainty for test points
    ood_prob = drop_model.predict(np.array(test_points))
    dropout_ood_probs.append(ood_prob)
    
    pred2 = drop_model.predict(grid_2d)[:,0].flatten()
    grid_preds.append(pred2)
# Out:
# Iteration: 1 Random p: 0.82 Test accuracy:  0.931
# Iteration: 2 Random p: 0.07 Test accuracy:  0.967
# Iteration: 3 Random p: 0.28 Test accuracy:  0.932
# Iteration: 4 Random p: 0.86 Test accuracy:  0.942
# Iteration: 5 Random p: 0.93 Test accuracy:  0.949
# Iteration: 6 Random p: 0.03 Test accuracy:  0.973
# Iteration: 7 Random p: 0.25 Test accuracy:  0.944
# Iteration: 8 Random p: 0.4 Test accuracy:  0.909
# Iteration: 9 Random p: 0.86 Test accuracy:  0.945
# Iteration: 10 Random p: 0.64 Test accuracy:  0.883
# Iteration: 11 Random p: 0.19 Test accuracy:  0.955
# Iteration: 12 Random p: 0.21 Test accuracy:  0.949
# Iteration: 13 Random p: 0.54 Test accuracy:  0.891
# Iteration: 14 Random p: 0.77 Test accuracy:  0.912
# Iteration: 15 Random p: 0.8 Test accuracy:  0.922
# Iteration: 16 Random p: 0.81 Test accuracy:  0.928
# Iteration: 17 Random p: 0.42 Test accuracy:  0.905
# Iteration: 18 Random p: 0.48 Test accuracy:  0.896
# Iteration: 19 Random p: 0.44 Test accuracy:  0.904
# Iteration: 20 Random p: 0.72 Test accuracy:  0.897
# Iteration: 21 Random p: 0.53 Test accuracy:  0.892
# Iteration: 22 Random p: 0.93 Test accuracy:  0.957
# Iteration: 23 Random p: 0.51 Test accuracy:  0.893
# Iteration: 24 Random p: 0.83 Test accuracy:  0.94
# Iteration: 25 Random p: 0.57 Test accuracy:  0.889
# Iteration: 26 Random p: 0.88 Test accuracy:  0.948
# Iteration: 27 Random p: 0.62 Test accuracy:  0.884
# Iteration: 28 Random p: 0.13 Test accuracy:  0.965
# Iteration: 29 Random p: 1.0 Test accuracy:  0.971
# Iteration: 30 Random p: 0.19 Test accuracy:  0.95

# %%
df = pd.DataFrame(np.array(drop_weights))

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0.95, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian dropout weights ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cos_similarity_plot_dropout.png".format(TOY_DATA_TYPE))

# %%
dropout_posterior_mean_preds = np.mean(np.array(dropout_post_predictions),axis=0)
dropout_posterior_mean_preds.shape
# Out:
# (1000, 1)

# %%
dropout_pred_test_labels = (dropout_posterior_mean_preds > 0.5).astype(np.int) 
dropout_acc_score = accuracy_score(Y_test, dropout_pred_test_labels)
print("Bayesian Dropout posterior predictive mean accuracy score for test data: ", dropout_acc_score)
# Out:
# Bayesian Dropout posterior predictive mean accuracy score for test data:  0.928

# %%
drop_ood_variance = np.std(np.array(dropout_ood_probs),axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], drop_ood_variance[i][0]))
# Out:
# uncertainty for test point: (0.5, -0.4) : 1.487238137087843e-07
# uncertainty for test point: (0.5, 0.8) : 1.989895963561139e-06
# uncertainty for test point: (0.5, 0.25) : 0.01953265070915222
# uncertainty for test point: (-0.8, 0.5) : 7.246023159268589e-08
# uncertainty for test point: (1.7, -0.3) : 4.316768453804798e-08
# uncertainty for test point: (-1.5, -3) : 5.699002728065672e-11
# uncertainty for test point: (-1.5, 3) : 2.5235913619220396e-12
# uncertainty for test point: (3, -3) : 1.2488972529756115e-12
# uncertainty for test point: (3, 3) : 0.002869943156838417

# %%
dropout_pred_test_labels.shape
# Out:
# (1000, 1)

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.mean(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for dropout model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_dropout.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.std(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for dropout model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_dropout.png".format(TOY_DATA_TYPE))

# %%
tsne = TSNE(n_components=2)
drop_test_probs_pca = tsne.fit_transform(np.array(dropout_post_predictions).reshape(30, 1000))


plt.scatter(drop_test_probs_pca[:,0], drop_test_probs_pca[:,1])
plt.title("TSNE plot of predictions for dropout model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_dropout.png".format(TOY_DATA_TYPE))

# %% [markdown]
# <a id='random'></a>
# ## 5. Random Subspace Sampling

# %%
models = []
random_weights= []
# iterate over different samples
for i in range(bayes_iters):
    # make a new NN with the same layout
    model2 = get_model(mc=False)
    # add random vector to presaved model weights
    model2.load_weights('initial_model_weights.h5')
    #Added scale to regularize randomness
    weights = [model2.get_weights()[j] + np.random.normal(size = model2.get_weights()[j].shape, scale=0.2) for j in range(len(model.get_weights()))]
    model2.set_weights(weights)
    #Get Dense model weights
    weights = model2.get_weights()
    flat_weight_array = np.array([])
    for weight in weights:
        flat_weight_array = np.concatenate((flat_weight_array, weight.flatten()))
    random_weights.append(flat_weight_array)
    models.append(model2)

# %%
random_post_predictions = []
grid_preds = []
random_ood_probs = []

for model in models: 
    y_pred = model.predict(X_test)
    random_post_predictions.append(y_pred)
    pred2 = model.predict(grid_2d)[:,0].flatten()
    grid_preds.append(pred2)
    #Predictions & uncertainty for test points
    ood_prob = model.predict(np.array(test_points))
    random_ood_probs.append(ood_prob)
    
random_posterior_mean_preds = np.mean(np.array(random_post_predictions),axis=0)
random_pred_test_labels = (random_posterior_mean_preds > 0.5).astype(np.int) 
random_acc_score = accuracy_score(Y_test, random_pred_test_labels)
print("Random subspace posterior predictive Test set mean accuracy score for test data: ", random_acc_score)
# Out:
# Random subspace posterior predictive Test set mean accuracy score for test data:  0.967

# %%
random_ood_variance = np.std(np.array(random_ood_probs),axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], random_ood_variance[i][0]))
# Out:
# uncertainty for test point: (0.5, -0.4) : 0.04570803791284561
# uncertainty for test point: (0.5, 0.8) : 0.08392439782619476
# uncertainty for test point: (0.5, 0.25) : 0.14357511699199677
# uncertainty for test point: (-0.8, 0.5) : 0.035081349313259125
# uncertainty for test point: (1.7, -0.3) : 0.05538316071033478
# uncertainty for test point: (-1.5, -3) : 0.004237053450196981
# uncertainty for test point: (-1.5, 3) : 5.568975325331849e-07
# uncertainty for test point: (3, -3) : 3.953562099923147e-08
# uncertainty for test point: (3, 3) : 0.09695739299058914

# %%
df = pd.DataFrame(np.array(random_weights))

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian random sampling ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cosine_similarity_plot_random.png".format(TOY_DATA_TYPE))

# %%
fig, ax = plt.subplots(figsize=(16, 9))
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
contour = ax.contourf(grid[0], grid[1], np.mean(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for random sampling model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_random.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], np.std(np.array(grid_preds),axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for random sampling model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_random.png".format(TOY_DATA_TYPE))

# %%
tsne = TSNE(n_components=2)
rand_test_probs_pca = tsne.fit_transform(np.array(random_post_predictions).reshape(30, 1000))


plt.scatter(rand_test_probs_pca[:,0], rand_test_probs_pca[:,1])
plt.title("TSNE plot of predictions for random sampling model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_random.png".format(TOY_DATA_TYPE))

# %% [markdown]
# <a id='hmc'></a>
# ## 6. HMC

# %%
def construct_nn(ann_input, ann_output):
    n_hidden1 = 64
    n_hidden2 = 8

    # Initialize random weights between each layer
    model = get_model(mc=False)
    model.load_weights('initial_model_weights.h5')
    ws = model.get_weights()
    init_1 = ws[0].astype(floatX)
    init_2 = ws[2].astype(floatX)
    init_out = ws[4].flatten().astype(floatX)
    init_b1 = ws[1].astype(floatX)
    init_b2 = ws[3].astype(floatX)
    init_bout = ws[5].astype(floatX)

    with pm.Model() as neural_network:
        # Trick: Turn inputs and outputs into shared variables using the data container pm.Data
        # It's still the same thing, but we can later change the values of the shared variable
        # (to switch in the test-data later) and pymc3 will just use the new data.
        # Kind-of like a pointer we can redirect.
        # For more info, see: http://deeplearning.net/software/theano/library/compile/shared.html
        ann_input = pm.Data('ann_input', ann_input)
        ann_output = pm.Data('ann_output', ann_output)

        # Weights from input to hidden layer
        weights_in_1 = pm.Normal('w_in_1', 0, sigma=1,
                                 shape=(X.shape[1], n_hidden1),
                                 testval=init_1)
        biases_in_1 = pm.Normal('b_in_1', 0, sigma=1,
                                 shape=(n_hidden1,),
                                 testval=init_b1)

        # Weights from 1st to 2nd layer
        weights_1_2 = pm.Normal('w_1_2', 0, sigma=1,
                                shape=(n_hidden1, n_hidden2),
                                testval=init_2)
        biases_1_2 = pm.Normal('b_1_2', 0, sigma=1,
                                 shape=(n_hidden2,),
                                 testval=init_b2)

        # Weights from hidden layer to output
        weights_2_out = pm.Normal('w_2_out', 0, sigma=1,
                                  shape=(n_hidden2,),
                                  testval=init_out)
        biases_2_out = pm.Normal('b_3_out', 0, sigma=1,
                                 shape=(1,),
                                 testval=init_bout)

        # Build neural-network using tanh activation function
        act_1 = pm.math.tanh(pm.math.dot(ann_input,
                                         weights_in_1)+biases_in_1)
        act_2 = pm.math.tanh(pm.math.dot(act_1,
                                         weights_1_2)+biases_1_2)
        act_out = pm.math.sigmoid(pm.math.dot(act_2,
                                              weights_2_out)+biases_2_out)

        # Binary classification -> Bernoulli likelihood
        out = pm.Bernoulli('out',
                           act_out,
                           observed=ann_output,
                           total_size=Y_train.shape[0] # IMPORTANT for minibatches
                          )
    return neural_network

neural_network = construct_nn(X_train, Y_train)

# %%
from pymc3.theanof import set_tt_rng, MRG_RandomStreams
set_tt_rng(MRG_RandomStreams(42))

# %%
with neural_network:
    steps = pm.NUTS()
    #use the specify sampler to sample from the posterior of the model
    trace = pm.sample(5000, step=steps, tune=1000, chains=1)
# Out:
# Sequential sampling (1 chains in 1 job)
# NUTS: [b_3_out, w_2_out, b_1_2, w_1_2, b_in_1, w_in_1]
# Sampling chain 0, 18 divergences: 100%|██████████| 6000/6000 [1:19:18<00:00,  1.26it/s]
# There were 18 divergences after tuning. Increase `target_accept` or reparameterize.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
pm.set_data(new_data={'ann_input': X_test, 'ann_output': Y_test}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)

# %%
pred = ppc["out"].mean(axis=0) > 0.5

# %%
print('Test Set Accuracy = {}%'.format((Y_test == pred).mean() * 100))
# Out:
# Test Set Accuracy = 97.3%

# %%
pm.set_data(new_data={'ann_input': np.array(test_points), 'ann_output': np.ones(len(test_points), dtype=np.int8)}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)
ood_variance = np.std(ppc["out"],axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], ood_variance[i]))
# Out:
# uncertainty for test point: (0.5, -0.4) : 0.003984000000000011
# uncertainty for test point: (0.5, 0.8) : 0.02909999999999981
# uncertainty for test point: (0.5, 0.25) : 0.240395999999998
# uncertainty for test point: (-0.8, 0.5) : 0.0
# uncertainty for test point: (1.7, -0.3) : 0.0019960000000000034
# uncertainty for test point: (-1.5, -3) : 0.2067359999999998
# uncertainty for test point: (-1.5, 3) : 0.029099999999999838
# uncertainty for test point: (3, -3) : 0.017676000000000074
# uncertainty for test point: (3, 3) : 0.24870399999999807

# %%
pm.set_data(new_data={'ann_input': grid_2d, 'ann_output': dummy_out}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)

# %%
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc["out"].mean(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for HMC model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_hmc.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc["out"].std(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for HMC model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_hmc.png".format(TOY_DATA_TYPE))

# %%
pm.set_data(new_data={'ann_input': grid_2d, 'ann_output': dummy_out}, model=neural_network)
ppc = pm.sample_posterior_predictive(trace, samples=500, progressbar=False, model=neural_network)["out"]
tsne = TSNE(n_components=2)
ppc_pca = tsne.fit_transform(ppc)


plt.plot(ppc_pca[:,0], ppc_pca[:,1], linestyle = "", marker = "o")
plt.title("TSNE plot of predictions for HMC model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_hmc.png".format(TOY_DATA_TYPE))

# %%
combined = trace["w_in_1"].reshape(-1, 64*2)
combined = np.concatenate((combined, trace["w_1_2"].reshape(-1, 64*8)), axis=1)
combined = np.concatenate((combined, trace["w_2_out"]), axis=1)
combined = np.concatenate((combined, trace["b_in_1"]), axis=1)
combined = np.concatenate((combined, trace["b_1_2"]), axis=1)
combined = np.concatenate((combined, trace["b_3_out"]), axis=1)

df = pd.DataFrame(np.array(combined)[-30:])

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian HMC model ({} data)".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cos_similarity_plot_hmc.png".format(TOY_DATA_TYPE))

# %% [markdown]
# <a id='advi'></a>
# ## 7. ADVI

# %%
neural_network = construct_nn(X_train, Y_train)

# %%
with neural_network:
    steps = pm.ADVI()
    #use the specify sampler to sample from the posterior of the model
    approx = pm.fit(n=30000, method=steps)
# Out:
# Average Loss = 468.44: 100%|██████████| 30000/30000 [00:58<00:00, 510.44it/s]
# Finished [100%]: Average Loss = 468.58

# %%
# create symbolic input
x_sym = T.matrix('X_test')
# symbolic number of samples is supported, we build vectorized posterior on the fly
n_sym = T.iscalar('n')
# Do not forget test_values or set theano.config.compute_test_value = 'off'
x_sym.tag.test_value = np.empty_like(X_test)
n_sym.tag.test_value = X_test.shape[1]
_sample_proba = approx.sample_node(neural_network.out.distribution.p,
                                   size=n_sym,
                                   more_replacements={neural_network['ann_input']: x_sym})
# Efficient vectorized form of sampling is used
sample_proba = theano.function([x_sym, n_sym], _sample_proba)
pred = (sample_proba(X_test, 500).mean(0) > 0.5) * 1
print('Test Set Accuracy = {}%'.format((Y_test == pred).mean() * 100))
# Out:
# Test Set Accuracy = 88.9%

# %%
ppc = sample_proba(test_points ,500)
ood_variance = np.std(ppc,axis=0)**2

for i in range(len(test_points)):
    print("uncertainty for test point: {} : {}".format(test_points[i], ood_variance[i]))
# Out:
# uncertainty for test point: (0.5, -0.4) : 0.004003673226152418
# uncertainty for test point: (0.5, 0.8) : 0.01284020832560912
# uncertainty for test point: (0.5, 0.25) : 0.07156165280460984
# uncertainty for test point: (-0.8, 0.5) : 0.016995864418628704
# uncertainty for test point: (1.7, -0.3) : 0.012853228912480965
# uncertainty for test point: (-1.5, -3) : 0.004322838912271944
# uncertainty for test point: (-1.5, 3) : 0.004104400671218783
# uncertainty for test point: (3, -3) : 0.0022061793843527987
# uncertainty for test point: (3, 3) : 0.020724825163422018

# %%
# populate grid with average predictions
ppc = sample_proba(grid_2d ,500)
cmap = sns.diverging_palette(250, 12, s=85, l=25, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc.mean(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive mean probabilities for ADVI model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('posterior predictive mean probability of class label = 0')
plt.savefig("{}_posterior_predictive_plot_advi.png".format(TOY_DATA_TYPE))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig, ax = plt.subplots(figsize=(16, 9))
contour = ax.contourf(grid[0], grid[1], ppc.std(axis=0).reshape(100, 100), cmap=cmap)
ax.scatter(X_test[Y_test==0, 0], X_test[Y_test==0, 1], color='b')
ax.scatter(X_test[Y_test==1, 0], X_test[Y_test==1, 1], color='r')
cbar = plt.colorbar(contour, ax=ax)
_ = ax.set(xlim=(-3, 3), ylim=(-3, 3), xlabel='X', ylabel='Y');
plt.title("posterior predictive uncertainty plot for ADVI model ({} data)".format(TOY_DATA_TYPE))
cbar.ax.set_ylabel('uncertainty (posterior predictive standard deviation)')
plt.savefig("{}_uncertainty_plot_advi.png".format(TOY_DATA_TYPE))

# %%
ppc = sample_proba(X_test ,500)
tsne = TSNE(n_components=2)
ppc_pca = tsne.fit_transform(ppc)


plt.plot(ppc_pca[:,0], ppc_pca[:,1], linestyle = "", marker = "o")
plt.title("TSNE plot of predictions for ADVI model ({} data)".format(TOY_DATA_TYPE))
plt.savefig("{}_tsne_plot_advi.png".format(TOY_DATA_TYPE))

# %%
combined = trace["w_in_1"].reshape(-1, 64*2)
combined = np.concatenate((combined, trace["w_1_2"].reshape(-1, 64*8)), axis=1)
combined = np.concatenate((combined, trace["w_2_out"]), axis=1)
combined = np.concatenate((combined, trace["b_in_1"]), axis=1)
combined = np.concatenate((combined, trace["b_1_2"]), axis=1)
combined = np.concatenate((combined, trace["b_3_out"]), axis=1)

df = pd.DataFrame(np.array(combined)[-30:])

fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(cosine_similarity(df),vmin=0, vmax=1, cmap="YlGnBu") # vmin=0.9, vmax=1
plt.title("cosine similarity of bayesian ADVI model ({} data) ".format(TOY_DATA_TYPE))
ax.invert_yaxis()
plt.savefig("{}_cosine_similarity_plot_advi.png".format(TOY_DATA_TYPE))
